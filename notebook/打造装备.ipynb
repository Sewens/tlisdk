# %% [markdown]
# # 打造装备的解析
#
# https://tlidb.com/cn/Craft

# %%
import requests
from bs4 import BeautifulSoup
import json
from urllib.parse import urljoin
import re # Import regular expressions module

# %% [markdown]
# ## 抓取装备列表

# %%
headers = {
    "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Language":"en,zh-CN;q=0.9,zh;q=0.8,ja;q=0.7",
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %%
def extract_chinese_chars(text):
    """
    从给定文本中提取所有中文字符。
    """
    # 正则表达式匹配所有 Unicode 中文字符
    # \u4e00-\u9fff 是基本汉字范围
    # 你可以根据需要扩展这个范围，例如加上中文标点 \u3000-\u303f
    chinese_chars = re.findall(r'[\u4e00-\u9fff]+', text)
    return "".join(chinese_chars)

def scrape_items_and_extract_chinese_name(url,headers):
    """
    直接从页面上所有 class="card-body" 的 div 中抓取装备词条，
    并提取中文名称。

    Args:
        url (str): 目标网页的URL.

    Returns:
        str: 包含抓取数据的JSON格式字符串，如果抓取失败或未找到数据则返回None。
    """
    scraped_data = []

    try:
        print(f"Fetching URL: {url}")
        response = requests.get(url, headers=headers, timeout=15)
        response.raise_for_status()
        html_content = response.text
        print("Successfully fetched page content.")
    except requests.exceptions.RequestException as e:
        print(f"请求页面时发生错误: {e}")
        return None
        
    soup = BeautifulSoup(html_content, 'html.parser')

    all_card_bodies = soup.find_all('div', class_='card-body')

    if not all_card_bodies:
        print("未能找到任何 class='card-body' 的 div 元素。")
        return None
    
    print(f"Found {len(all_card_bodies)} div elements with class 'card-body'. Processing all of them.")

    for i, card_body in enumerate(all_card_bodies):
        print(f"Processing card-body #{i+1}...")
        item_links_in_body = card_body.find_all('a', class_='p-2', href=True)

        if not item_links_in_body:
            print(f"  Card-body #{i+1} contains no <a> tags with class 'p-2' and href.")
            continue

        for a_tag in item_links_in_body:
            original_name = a_tag.get_text(strip=True)
            chinese_name = extract_chinese_chars(original_name)
            relative_link = a_tag['href']
            full_link = urljoin(url, relative_link)

            if original_name and full_link: # Ensure we have original name and link
                entry = {
                    "name_cn": chinese_name if chinese_name else original_name, # Fallback if no Chinese chars found
                    "name_original": original_name,
                    "link": full_link
                }
                scraped_data.append(entry)
        
        # Changed print statement slightly to reflect what's being counted
        extracted_count = sum(1 for item in scraped_data if item['link'].startswith(urljoin(url, ""))) # Count items from this card_body
        print(f"  Potentially extracted items from card-body #{i+1}. Total items so far: {len(scraped_data)}")


    if not scraped_data:
        print("未能从任何 'card-body' 中提取到有效的装备信息。")
        return None

    return json.dumps(scraped_data, ensure_ascii=False, indent=4)

# %%
target_page_url = "https://tlidb.com/cn/Craft"
json_data = scrape_items_and_extract_chinese_name(target_page_url,headers)

if json_data:
    print("\n成功从所有 'card-body' 区域抓取到数据：")
else:
    print("\n抓取失败或未找到数据。请检查上面的日志输出。")
# Out:
# Fetching URL: https://tlidb.com/cn/Craft
# Successfully fetched page content.
# <!DOCTYPE html>
# <html lang="cn" data-bs-theme="dark">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <title>火炬编年史, Torchlight: Infinite Wiki</title>
#     <meta name="color-scheme" content="dark">
#     <link href="/favicon.ico" rel="shortcut icon" >
#
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.3.1/css/bootstrap.min.css" integrity="sha512-Z/def5z5u2aR89OuzYcxmDJ0Bnd5V1cKqBEbvLOiUNWdg9PQeXVvXLI90SE4QOHGlfLqUnDNVAYyZi8UwUTmWQ==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.13.2/themes/base/jquery-ui.min.css" integrity="sha512-ELV+xyi8IhEApPS/pSj66+Jiw+sOT1Mqkzlh8ExXihe4zfqbWkxPRi8wptXIO9g73FSlhmquFlUOuMSoXz5IRw==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css" integrity="sha512-xh6O/CkQoPOWDdYTDqeRdPCVd1SpvCA9XXcUnZS2FmJNp1coAFzvtCN9BmamE+4aHK8yyUHUSCcJHgXloTyT2A==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#     <link rel="stylesheet" href="https://cdn.datatables.net/1.12.1/css/dataTables.bootstrap5.min.css" crossorigin="anonymous"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datepicker/1.9.0/css/bootstrap-datepicker.min.css" integrity="sha512-mSYUmp1HYZDFaVKK//63EcZq4iFWFjxSL+Z3T/aCt4IO9Cejm03q3NKKYN6pFQzY0SBOr8h+eCIAZHPXcpZaNw==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/limonte-sweetalert2/11.6.16/sweetalert2.min.css" integrity="sha512-NvuRGlPf6cHpxQqBGnPe7fPoACpyrjhlSNeXVUY7BZAj1nNhuNpRBq3osC4yr2vswUEuHq2HtCsY2vfLNCndYA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/modal-video@2.4.6/css/modal-video.min.css" integrity="sha256-nd8IBqNn9uqwZKfZcLIXQcNxk5TjqrxiLx7PzN5PFW0=" crossorigin="anonymous">
#     <link rel="stylesheet" href="/css/stdtheme.css?1744782838
# "/>
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.3.1/js/bootstrap.bundle.min.js" integrity="sha512-ToL6UYWePxjhDQKNioSi4AyJ5KkRxY+F1+Fi7Jgh0Hp5Kk2/s8FD7zusJDdonfe5B00Qw+B8taXxF6CFLnqNCw==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.1/jquery.min.js" integrity="sha512-aVKKRRi/Q/YV+4mjoKBsE4x3H+BkegoM/em46NNlCqNTmUYADjBbeNefNxYV7giUp0VxICtqdrbqU7iVaeZNXA==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.13.2/jquery-ui.min.js" integrity="sha512-57oZ/vW8ANMjR/KQ6Be9v/+/h6bq9/l3f0Oc7vn6qMqyhvPd1cvKBRWWpzu0QoneImqr2SkmO4MSqU+RpHom3Q==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://cdn.datatables.net/1.12.1/js/jquery.dataTables.min.js" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://cdn.datatables.net/1.12.1/js/dataTables.bootstrap5.min.js" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery.countdown/2.2.0/jquery.countdown.min.js" integrity="sha512-lteuRD+aUENrZPTXWFRPTBcDDxIGWe5uu0apPEn+3ZKYDwDaEErIK9rvR0QzUGmUQ55KFE2RqGTVoZsKctGMVw==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://unpkg.com/@popperjs/core@2" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://unpkg.com/tippy.js@6" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datepicker/1.9.0/js/bootstrap-datepicker.min.js" integrity="sha512-T/tUfKSV1bihCnd+MxKD0Hm1uBBroVYBOYSk1knyvQ9VyZJpc/ALb4P0r6ubwVPSGB2GvjeoMAJJImBG12TiaQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/limonte-sweetalert2/11.6.16/sweetalert2.all.min.js" integrity="sha512-4tvE14sHIcdIHl/dUdMHp733PI6MpYA7BDnDfndQmx7aIovEkW+LfkonVO9+NPWP1jYzmrqXJMIT2tECv1TsEQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <!--<script src="https://unpkg.com/mustache@latest" crossorigin="anonymous" referrerpolicy="no-referrer"></script>-->
#     <script src="https://cdn.jsdelivr.net/npm/modal-video@2.4.6/js/modal-video.min.js" integrity="sha256-VqINwNxkS4VEDMq5O52YTckX+Mx84X6bafO8NxF21Xw=" crossorigin="anonymous"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/tinymce/6.3.1/tinymce.min.js" integrity="sha512-eV68QXP3t5Jbsf18jfqT8xclEJSGvSK5uClUuqayUbF5IRK8e2/VSXIFHzEoBnNcvLBkHngnnd3CY7AFpUhF7w==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#     <script src="/js/header.js?1744782838
# "></script>
#     <script src="/js/footer.js?1744782838
# "></script>
#
#
#
# <script data-cfasync="false">window.nitroAds=window.nitroAds||{createAd:function(){return new Promise(e=>{window.nitroAds.queue.push(["createAd",arguments,e])})},addUserToken:function(){window.nitroAds.queue.push(["addUserToken",arguments])},queue:[]};</script>
# <script data-cfasync="false" async src="https://s.nitropay.com/ads-1573.js"></script>
#
#   </head>
#   <body>
#     <div class="background-image"></div>
#     <!-- Google tag (gtag.js) -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=G-P6KT6L9KX8"></script>
#     <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-P6KT6L9KX8');
#     </script>
#
#     <nav class="navbar navbar-expand-lg navbar-dark">
#       <div class="container">
#         <a class="navbar-brand" href="/cn/" data-i18n="TLIDB">TLIDB</a>
#         <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">
#           <span class="navbar-toggler-icon"></span>
#         </button>
#         <div class="collapse navbar-collapse" id="navbarSupportedContent">
#           <ul class="navbar-nav me-auto mb-2 mb-lg-0">
#             <li class="nav-item dropdown">
#               <a data-i18n="HeroRanking|name|1" class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">
#                 Hero
#               </a>
#               <ul class="dropdown-menu">
#                 <li><a class="dropdown-item" data-i18n="HeroRanking|name|1" href="/cn/Hero">Hero</a></li>
#                 <li><a class="dropdown-item" data-i18n="handbook|name|30010" href="/cn/Talent">Talent</a></li>
#               </ul>
#             </li>
#
#             <li class="nav-item dropdown">
#               <a data-i18n="function|name|115" class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">
#                 Stash
#               </a>
#               <ul class="dropdown-menu">
#                 <li><a class="dropdown-item" data-i18n="function|name|115" href="/cn/Inventory">Stash</a></li>
#                 <li><a class="dropdown-item" data-i18n="AuctionHouse_rough_search|description|1" href="/cn/Legendary_Gear">Legendary Gear</a></li>
#                 <!--<li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_Synthetic_Synthetic" href="/cn/Recipe">Recipe</a></li>-->
#                 <li><a class="dropdown-item" data-i18n="function|name|130" href="/cn/Pactspirit">Pactspirit</a></li>
#                 <!--<li><a class="dropdown-item" data-i18n="function|name|116" href="/cn/Black_Market">Black Market</a></li>-->
#                 <li><a class="dropdown-item" href="/cn/Drop_Source" data-i18n="TextTable_GameFunc|value|Func_Tips_DropSource">Drop Source</a></li>
#                 <li><a class="dropdown-item" href="/cn/Destiny" data-i18n="manual_ruledes_filter|des|200503">Destiny</a></li>
#               </ul>
#             </li>
#
#             <li class="nav-item dropdown">
#               <a data-i18n="function|name|100" class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">
#                 Skill
#               </a>
#               <ul class="dropdown-menu">
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_SkillBag_SkillType1" href="/cn/Active_Skill">Active Skill</a></li>
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_SkillBag_SkillType2" href="/cn/Support_Skill">Support Skill</a></li>
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_SkillBag_SkillType3" href="/cn/Passive_Skill">Passive Skill</a></li>
#                 <!--<li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_SkillBag_SkillType4" href="/cn/Triggered_Skill">Triggered Skill</a></li>-->
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_SkillBag_SkillType5" href="/cn/Activation_Medium_Skill">Activation Medium Skill</a></li>
#                 <li><a class="dropdown-item" data-i18n="item_type_list|name|50606" href="/cn/Noble_Support_Skill">Noble Support Skill</a></li>
#                 <li><a class="dropdown-item" data-i18n="item_type_list|name|50605" href="/cn/Magnificent_Support_Skill">Magnificent Support Skill</a></li>
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_Common_Mind" href="/cn/Tip">Tip</a></li>
#                 <li><a class="dropdown-item" href="/cn/Hyperlink">Hyperlink</a></li>
#               </ul>
#             </li>
#
#             <li class="nav-item dropdown">
#               <a data-i18n="function|name|128" class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">
#                 Craft
#               </a>
#               <ul class="dropdown-menu">
#                 <!--<li><a class="dropdown-item" data-i18n="function|name|131" href="/cn/Enchant">Enchant</a></li>-->
#                 <li><a class="dropdown-item" data-i18n="function|name|133" href="/cn/Corrosion">Corrosion</a></li>
#                 <li><a class="dropdown-item" data-i18n="function|name|128" href="/cn/Craft">Craft</a></li>
#                 <li><a class="dropdown-item" data-i18n="function|name|901" href="/cn/Gear_Empowerment">Gear Empowerment</a></li>
#                 <li><a class="dropdown-item" data-i18n="item_base|name|80001" href="/cn/Soul_Candle">Soul Candle</a></li>
#                 <li><a class="dropdown-item" data-i18n="manual_rule|name|60000111" href="/cn/Dream_Talking">Dream Talking</a></li>
#                 <li><a class="dropdown-item" data-i18n="system_help|name|38" href="/cn/Blending_Rituals"></a></li>
#               </ul>
#             </li>
#
#             <li class="nav-item dropdown">
#               <a data-i18n="function|name|125" class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">
#                 Merits
#               </a>
#               <ul class="dropdown-menu">
#                 <!--
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_Growth_Achievement_Title" href="/cn/Path_of_Achievements">Path of Achievements</a></li>
#                 -->
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_Growth_GrowPath_Title" href="/cn/Path_of_Progression">Path of Progression</a></li>
#                 <!--<li><a class="dropdown-item" data-i18n="season|name1|101" href="/cn/Dark_Surge_Season">Dark Surge Season</a></li>-->
#                 <!--<li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_SeasonBook_Title" href="/cn/Season_Pass">Season Pass</a></li>-->
#                 <!--
#                 <li><a class="dropdown-item" data-i18n="function|name|139" href="/cn/Event">Event</a></li>
#                 -->
#                 <li><hr class="dropdown-divider"></li>
#                 <li><a class="dropdown-item" data-i18n="function|name|122" href="/cn/Help">Help</a></li>
#                 <li><a class="dropdown-item" data-i18n="function|name|124" href="/cn/Codex">Codex</a></li>
#               </ul>
#             </li>
#
#             <li class="nav-item dropdown">
#               <a data-i18n="system_help|name|8" class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">
#                 Netherrealm
#               </a>
#               <ul class="dropdown-menu">
#                 <li><a class="dropdown-item" data-i18n="system_help|name|8" href="/cn/Netherrealm">Netherrealm</a></li>
#                 <!--<li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_MysteryCard_PlayerDeck" href="/cn/Trait_Decks">Trait Decks</a></li>-->
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_MysteryCard_AdditionDeck" href="/cn/Confusion_Card_Library">Confusion Card Library</a></li>
#                 <li><a class="dropdown-item" data-i18n="function|name|171" href="/cn/Void_Chart">Void Chart</a></li>
#                 <li><a class="dropdown-item" data-i18n="item_type_list|name|51001" href="/cn/Compass">Compass</a></li>
#                 <li><a class="dropdown-item" data-i18n="item_type_list|name|51002" href="/cn/Probe">Probe</a></li>
#                 <li><hr class="dropdown-divider"></li>
#                 <li><a class="dropdown-item" data-i18n="function|name|137" href="/cn/Path_of_the_Brave">Path of the Brave</a></li>
#               </ul>
#             </li>
#
#             <li class="nav-item dropdown">
#               <a data-i18n="function|name|110" class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">
#                 Shop
#               </a>
#               <ul class="dropdown-menu">
#     <!--
#                 <li><a class="dropdown-item" data-i18n="function|name|110" href="/cn/Shop">Shop</a></li>
#     -->
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_Fashion_Type1" href="/cn/Outfit">Outfit</a></li>
#                 <li><a class="dropdown-item" data-i18n="TextTable_GameFunc|value|Func_Pack_Currency_Tab" href="/cn/Commodity">Commodity</a></li>
#                 <li><a class="dropdown-item" data-i18n="function|name|132" href="/cn/Boon">Boon</a></li>
#               </ul>
#             </li>
#
#     <!--
#             <li class="nav-item">
#               <a class="nav-link" data-i18n="Guide" href="/cn/guides?season=The%20Frozen%20Canvas%20Season">Guide</a>
#             </li>
#     -->
#
#           </ul>
#
#           <!--
#           <a class="nav-link2" style="padding-right: 10px" href="https://lihi1.com/cAO3Z" target="_blank">
#             <img style="height: 24px"
#                 src="https://cdn.tlidb.com/image/logo/torchlight-48.webp"
#             />
#           </a>
#
#           <a class="nav-link2" style="padding-right: 10px"
#             href="https://lihi1.com/l1NmL"
#             target="_blank">
#             <img style="height: 24px" src="https://cdn.tlidb.com/image/logo/facebook-48.webp"/>
#           </a>
#
#           <a class="nav-link2" style="padding-right: 10px"
#             href="https://lihi1.com/neCTK"
#             target="_blank">
#             <img style="height: 24px" src="https://cdn.tlidb.com/image/logo/youtube-48.webp"/>
#           </a>
#
#           <a class="nav-link2" style="padding-right: 10px" href="https://lihi1.com/owKrQ" target="_blank">
#             <img style="height: 24px" src="https://cdn.tlidb.com/image/logo/discord-48.webp"/>
#           </a>
#           -->
#
#           <ul class="navbar-nav">
#             <li class="nav-item dropdown">
#               <a href="#" class="nav-link dropdown-toggle" role="button" data-bs-toggle="dropdown" aria-haspopup="true" aria-expanded="false"> <i class="fas fa-language fa-lg"></i></a>
#               <ul class="dropdown-menu language-menu">
#                 <li><a class='dropdown-item' href='/en/'>EN English</a></li>
#                 <li><a class='dropdown-item' href='/tw/'>TW 繁體中文</a></li>
#                 <li><a class='dropdown-item' href='/cn/'>CN 简体中文</a></li>
#                 <li><a class='dropdown-item' href='/ko/'>KO 한국어</a></li>
#                 <li><a class='dropdown-item' href='/ja/'>JA Japanese</a></li>
#                 <!--
#                 <li><a class='dropdown-item' href='/ru/'>RU Русский</a></li>
#                 <li><a class='dropdown-item' href='/de/'>DE Deutsch</a></li>
#                 <li><a class='dropdown-item' href='/es/'>ES Spanish</a></li>
#                 <li><a class='dropdown-item' href='/fr/'>FR Français</a></li>
#                 <li><a class='dropdown-item' href='/id/'>ID bahasa Indonesia</a></li>
#                 <li><a class='dropdown-item' href='/pt/'>PT Português</a></li>
#                 <li><a class='dropdown-item' href='/th/'>TH ภาษาไทย</a></li>
#                 <li><a class='dropdown-item' href='/vi/'>VI Tiếng Việt</a></li>
#                 -->
#               </ul>
#             </li>
#           </ul>
#
#           <form class="d-flex" role="search" action="search">
#             <input class="form-control me-2" type="search" placeholder="Search" aria-label="Search" id="navautosearch" name="q">
#           </form>
#
#         </div>
#       </div>
#     </nav>
#
#     <script> sidebar160("leftside_banner", "left"); </script>
#     <script> sidebar160("rightside_banner", "right"); </script>
#
#     <div class="page">
#     <div class="page-content container" role="main">
#     <div class="text-center">
#     <a href="Whispering_Mist_Season"><img src="https://cdn.tlidb.com/UI/Textures/Common/Icon/GamePlay/UI_S6Gameplay_Tile_bench.webp" class="size48"/></a>
#     <a href="Nightmare_Season"><img src="https://cdn.tlidb.com/UI/Textures/Common/Icon/GamePlay/UI_Item_S5Gameplay_DreamTreasure_Almighty_C_128.webp" class="size48"/></a>
#     <a href="Aeterna_Season"><img src="https://cdn.tlidb.com/UI/Textures/Common/Icon/Silhouette/Talent/S4/UI_S4Gameplay_talent01_Icon_128.webp" class="size48"/></a>
#     <a href="Cube_Season"><img src="https://cdn.tlidb.com/UI/Textures/Common/Icon/Item/128/UI_S3Gameplay_Beads_Icon_128.webp" class="size48"/></a>
#     <a href="Blacksail_Season"><img src="https://cdn.tlidb.com/UI/Textures/Common/Icon/Item/128/UI_S2BossTicket3_Icon_128.webp" class="size48"/></a>
#     <a href="Dark_Surge_Season"><img src="https://cdn.tlidb.com/UI/Textures/Common/Icon/Item/128/UI_Item_yimozhihe_Icon_128.webp" class="size48"/></a>
#     </div>
#     <div class="text-center mb-2"><a href="https://torchlight.xd.cn/" target="_blank"><img src="https://cdn.tlidb.com/image/torchlight/p3_20250512_cn.gif" style="max-width: 100%;"/></a></div>
#     <div class="card">
#     <div class="card-header" data-i18n="sp_card_class_v2|name|2">Gear</div>
#     <div class="card-body">
#         <div>
#             <span data-i18n="HeroRanking_equip_tag|description|3" class="p-2">Helmet</span>:
#             <a href="STR_Helmet" data-i18n="item_type_list|name|10101" class="p-2">STR Helmet</a>
#             <a href="DEX_Helmet" data-i18n="item_type_list|name|10102" class="p-2">DEX Helmet</a>
#             <a href="INT_Helmet" data-i18n="item_type_list|name|10103" class="p-2">INT Helmet</a>
#         </div>
#         <div>
#             <span data-i18n="HeroRanking_equip_tag|description|4" class="p-2">Chest Armor</span>:
#             <a href="STR_Chest_Armor" data-i18n="item_type_list|name|10201" class="p-2">STR Chest Armor</a>
#             <a href="DEX_Chest_Armor" data-i18n="item_type_list|name|10202" class="p-2">DEX Chest Armor</a>
#             <a href="INT_Chest_Armor" data-i18n="item_type_list|name|10203" class="p-2">INT Chest Armor</a>
#         </div>
#         <div>
#             <span data-i18n="HeroRanking_equip_tag|description|6" class="p-2">Gloves</span>:
#             <a href="STR_Gloves" data-i18n="item_type_list|name|10301" class="p-2">STR Gloves</a>
#             <a href="DEX_Gloves" data-i18n="item_type_list|name|10302" class="p-2">DEX Gloves</a>
#             <a href="INT_Gloves" data-i18n="item_type_list|name|10303" class="p-2">INT Gloves</a>
#         </div>
#         <div>
#             <span data-i18n="HeroRanking_equip_tag|description|5" class="p-2">Boots</span>:
#             <a href="STR_Boots" data-i18n="item_type_list|name|10401" class="p-2">STR Boots</a>
#             <a href="DEX_Boots" data-i18n="item_type_list|name|10402" class="p-2">DEX Boots</a>
#             <a href="INT_Boots" data-i18n="item_type_list|name|10403" class="p-2">INT Boots</a>
#         </div>
#         <div>
#             <span data-i18n="item_base|description2|5" class="p-2">One-handed</span>:
#             <a href="Claw" data-i18n="item_type_list|name|10501" class="p-2">Claw</a>
#             <a href="Dagger" data-i18n="item_type_list|name|10502" class="p-2">Dagger</a>
#             <a href="One-Handed_Sword" data-i18n="item_type_list|name|10503" class="p-2">One-Handed Sword</a>
#             <a href="One-Handed_Hammer" data-i18n="item_type_list|name|10504" class="p-2">One-Handed Hammer</a>
#             <a href="One-Handed_Axe" data-i18n="item_type_list|name|10505" class="p-2">One-Handed Axe</a>
#             <a href="Wand" data-i18n="item_type_list|name|10509" class="p-2">Wand</a>
#             <a href="Rod" data-i18n="item_type_list|name|10510" class="p-2">Rod</a>
#             <a href="Scepter" data-i18n="item_type_list|name|10511" class="p-2">Scepter</a>
#             <a href="Cane" data-i18n="item_type_list|name|10512" class="p-2">Cane</a>
#             <a href="Pistol" data-i18n="item_type_list|name|10515" class="p-2">Pistol</a>
#         </div>
#         <div>
#             <span data-i18n="item_base|description2|19" class="p-2">Two-handed</span>:
#             <a href="Two-Handed_Sword" data-i18n="item_type_list|name|10506" class="p-2">Two-Handed Sword</a>
#             <a href="Two-Handed_Hammer" data-i18n="item_type_list|name|10507" class="p-2">Two-Handed Hammer</a>
#             <a href="Two-Handed_Axe" data-i18n="item_type_list|name|10508" class="p-2">Two-Handed Axe</a>
#             <a href="Tin_Staff" data-i18n="item_type_list|name|10513" class="p-2">Tin Staff</a>
#             <a href="Cudgel" data-i18n="item_type_list|name|10514" class="p-2">Cudgel</a>
#             <a href="Bow" data-i18n="item_type_list|name|10516" class="p-2">Bow</a>
#             <a href="Crossbow" data-i18n="item_type_list|name|10517" class="p-2">Crossbow</a>
#             <a href="Musket" data-i18n="item_type_list|name|10518" class="p-2">Musket</a>
#             <a href="Fire_Cannon" data-i18n="item_type_list|name|10519" class="p-2">Fire Canon</a>
#         </div>
#         <div>
#             <span data-i18n="item_type_list|name|106" class="p-2">Shield</span>:
#             <a href="STR_Shield" data-i18n="item_type_list|name|10601" class="p-2">STR Shield</a>
#             <a href="DEX_Shield" data-i18n="item_type_list|name|10602" class="p-2">DEX Shield</a>
#             <a href="INT_Shield" data-i18n="item_type_list|name|10603" class="p-2">INT Shield</a>
#         </div>
#         <div>
#             <span data-i18n="item_type_list|name|207" class="p-2">Trinket</span>:
#             <a href="Necklace" data-i18n="item_type_list|name|10701" class="p-2">Necklace</a>
#             <a href="Ring" data-i18n="item_type_list|name|10702" class="p-2">Ring</a>
#             <a href="Belt" data-i18n="item_type_list|name|10704" class="p-2">Belt</a>
#             <a href="Spirit_Ring" data-i18n="item_type_list|name|10703" class="p-2">Spirit Ring</a>
#         </div>
#         <div>
#             <span data-i18n="HeroRanking|name|1" class="p-2">Hero</span>:
#         <!--
#             <a href="Hero_Relic" data-i18n="TextTable_GameFunc|value|Func_ManualV2_AffixType8" class="p-2">Hero Relic</a>
#         -->
#             <a href="Hero_Memories" data-i18n="hyperlink|name|40323" class="p-2">Hero Memories</a>
#             <a href="Divinity_Slate" data-i18n="hyperlink|name|40347" class="p-2">Divinity Slate</a>
#         </div>
#     </div>
# </div>
# <ul class="nav nav-tabs d-flex flex-wrap" role="tablist"><li class="nav-item" role="presentation"><button class="nav-link active" data-bs-toggle="tab" role="tab" aria-selected="true" data-bs-target="#T1forge词缀">T1 forge 词缀</button></li><li class="nav-item" role="presentation"><button class="nav-link" data-bs-toggle="tab" role="tab" aria-selected="false" data-bs-target="#打造">打造</button></li></ul><div class="tab-content"><div id="T1forge词缀" class="tab-pane fade show active"><h1>T1 forge 词缀</h1>
#
# <script>
# $(document).ready(function() {
#     $(".myInput").on("keyup", function() {
#         var value = $(this).val().toLowerCase();
#         $(".myTable tr").filter(function() {
#             $(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
#         });
#     });
# });
# </script>
# <input class="form-control myInput" placeholder="Filter"/>
#
# <div class="row">
#   <div class="col-lg-6">
#     <table class="table table-hover table-striped table-sm myTable">
#     <caption style="caption-side: top"></caption>
#     <thead>
#       <tr><th>Tier<th>Modifier<th>Lv<th>Weight<th>Type
#     </thead>
#     <tbody>
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(127&ndash;180)</span> 最大魔力<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(64&ndash;90)</span>% 魔力自然回复速度<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(35&ndash;48)</span>% 最大魔力<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(253&ndash;360)</span> 最大魔力<td>86<td>100<td>锡杖
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(68&ndash;96)</span>% 最大魔力<td>86<td>100<td>锡杖
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(155&ndash;220)</span> 最大生命<td>86<td>100<td>项链
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(155&ndash;220)</span> 最大生命<td>86<td>100<td>戒指
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% 攻击与法术格挡率<td>86<td>100<td>戒指
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(155&ndash;220)</span> 最大生命<td>86<td>100<td>腰带
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% 攻击与法术格挡率<td>86<td>100<td>腰带
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(85&ndash;120)</span> 最大魔力<td>86<td>100<td>腰带
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(127&ndash;180)</span> 最大魔力<td>86<td>100<td>法杖
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(34&ndash;48)</span>% 最大魔力<td>86<td>100<td>法杖
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(127&ndash;180)</span> 最大魔力<td>86<td>100<td>魔杖
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(155&ndash;220)</span> 最大生命<td>86<td>100<td>力量手套
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(155&ndash;220)</span> 最大生命<td>86<td>100<td>敏捷手套
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(85&ndash;120)</span> 最大魔力<td>86<td>100<td>智慧手套
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(43&ndash;60)</span>% 魔力自然回复速度<td>86<td>100<td>智慧手套
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(154&ndash;220)</span> 最大生命<td>86<td>100<td>力量鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% 攻击与法术格挡率<td>86<td>100<td>力量鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(154&ndash;220)</span> 最大生命<td>86<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% 攻击与法术格挡率<td>86<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% 攻击与法术格挡率<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(84&ndash;120)</span> 最大魔力<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(154&ndash;220)</span> 最大生命<td>86<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% 攻击与法术格挡率<td>86<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(154&ndash;220)</span> 最大生命<td>86<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% 攻击与法术格挡率<td>86<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% 攻击与法术格挡率<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(85&ndash;120)</span> 最大魔力<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(154&ndash;220)</span> 最大生命<td>86<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(154&ndash;220)</span> 最大生命<td>86<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(84&ndash;120)</span> 最大魔力<td>86<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(232&ndash;330)</span> 最大生命<td>86<td>100<td>力量盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(232&ndash;330)</span> 最大生命<td>86<td>100<td>敏捷盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 最大生命<td>86<td>100<td>敏捷盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 最大生命<td>86<td>100<td>力量盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(169&ndash;240)</span> 最大魔力<td>86<td>100<td>智慧盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(155&ndash;220)</span> 最大生命<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(11&ndash;16)</span>% 生命自然回复速度<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(127&ndash;180)</span> 最大魔力<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(48&ndash;60)</span>% 魔力自然回复速度<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(245&ndash;350)</span> 最大护盾<td>86<td>100<td>项链
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(245&ndash;350)</span> 最大护盾<td>86<td>100<td>戒指
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(246&ndash;350)</span> 最大护盾<td>86<td>100<td>腰带
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(2017&ndash;2880)</span> 该装备护甲值<td>86<td>100<td>力量手套
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(2017&ndash;2880)</span> 该装备闪避值<td>86<td>100<td>敏捷手套
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(239&ndash;340)</span> 该装备护盾<td>86<td>100<td>智慧手套
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(47&ndash;66)</span>% 该装备护盾<td>86<td>100<td>智慧手套
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(2017&ndash;2880)</span> 该装备护甲值<td>86<td>100<td>力量鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(2017&ndash;2880)</span> 该装备闪避值<td>86<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(239&ndash;340)</span> 该装备护盾<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(47&ndash;66)</span>% 该装备护盾<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(2353&ndash;3360)</span> 该装备护甲值<td>86<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(43&ndash;60)</span>% 暴击伤害减免<td>86<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(2353&ndash;3360)</span> 该装备闪避值<td>86<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(281&ndash;400)</span> 该装备护盾<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(47&ndash;66)</span>% 该装备护盾<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(43&ndash;60)</span>% 暴击伤害减免<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(2017&ndash;2880)</span> 该装备护甲值<td>86<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(10&ndash;13)</span>% <e id=501 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="格挡时默认抵消 30% 伤害。增加格挡比例，可以提升抵消伤害的比例。">格挡比例</e><td>86<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(2017&ndash;2880)</span> 该装备闪避值<td>86<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(10&ndash;13)</span>% <e id=501 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="格挡时默认抵消 30% 伤害。增加格挡比例，可以提升抵消伤害的比例。">格挡比例</e><td>86<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(239&ndash;340)</span> 该装备护盾<td>86<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(47&ndash;66)</span>% 该装备护盾<td>86<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(10&ndash;13)</span>% <e id=501 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="格挡时默认抵消 30% 伤害。增加格挡比例，可以提升抵消伤害的比例。">格挡比例</e><td>86<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(3025&ndash;4320)</span> 该装备护甲值<td>86<td>100<td>力量盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(14&ndash;19)</span>% 攻击与法术格挡率<td>86<td>100<td>力量盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% <e id=501 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="格挡时默认抵消 30% 伤害。增加格挡比例，可以提升抵消伤害的比例。">格挡比例</e><td>86<td>100<td>力量盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(3025&ndash;4320)</span> 该装备闪避值<td>86<td>100<td>敏捷盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(14&ndash;19)</span>% 攻击与法术格挡率<td>86<td>100<td>敏捷盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% <e id=501 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="格挡时默认抵消 30% 伤害。增加格挡比例，可以提升抵消伤害的比例。">格挡比例</e><td>86<td>100<td>敏捷盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(14&ndash;19)</span>% 攻击与法术格挡率<td>86<td>100<td>智慧盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;15)</span>% <e id=501 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="格挡时默认抵消 30% 伤害。增加格挡比例，可以提升抵消伤害的比例。">格挡比例</e><td>86<td>100<td>智慧盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(245&ndash;350)</span> 最大护盾<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(36&ndash;38)</span> - <span class="text-mod">(44&ndash;46)</span> 点物理伤害<td>86<td>100<td>爪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(123&ndash;125)</span> - <span class="text-mod">(160&ndash;169)</span> 点火焰伤害<td>86<td>100<td>爪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(125&ndash;127)</span> - <span class="text-mod">(165&ndash;167)</span> 点冰冷伤害<td>86<td>100<td>爪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(14&ndash;16)</span> - <span class="text-mod">(276&ndash;278)</span> 点闪电伤害<td>86<td>100<td>爪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(133&ndash;135)</span> - <span class="text-mod">(157&ndash;159)</span> 点腐蚀伤害<td>86<td>100<td>爪
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(89&ndash;102)</span> - <span class="text-mod">(110&ndash;138)</span> 点火焰伤害<br/>召唤物附加 <span class="text-mod">(89&ndash;102)</span> - <span class="text-mod">(110&ndash;138)</span> 点火焰伤害<td>86<td>100<td>进阶词缀
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(89&ndash;102)</span> - <span class="text-mod">(110&ndash;138)</span> 点冰冷伤害<br/>召唤物附加 <span class="text-mod">(89&ndash;102)</span> - <span class="text-mod">(110&ndash;138)</span> 点冰冷伤害<td>86<td>100<td>进阶词缀
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(11&ndash;12)</span> - <span class="text-mod">(150&ndash;228)</span> 点闪电伤害<br/>召唤物附加 <span class="text-mod">(11&ndash;12)</span> - <span class="text-mod">(150&ndash;228)</span> 点闪电伤害<td>86<td>100<td>进阶词缀
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(97&ndash;111)</span> - <span class="text-mod">(113&ndash;129)</span> 点腐蚀伤害<br/>召唤物附加 <span class="text-mod">(97&ndash;111)</span> - <span class="text-mod">(113&ndash;129)</span> 点腐蚀伤害<td>86<td>100<td>进阶词缀
#     <tr data-tier="1"><td>1<td>附加 <span class="text-mod">(77&ndash;100)</span> 基础<e id=712 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="触电状态是指闪电伤害击中时有概率引发的异常状态，受触电几率影响&lt;br/&gt;处于触电状态的敌人每次被击中时，额外结算 1 次触电伤害&lt;br/&gt;触电伤害为间接闪电伤害，不受加成影响并且无视抗性&lt;br/&gt;单次触电状态最多被结算 12 次&lt;br/&gt;基础触电伤害为 0 时，无法造成触电">触电</e>伤害<td>86<td>100<td>进阶词缀
#     <tr data-tier="1"><td>1<td>附加 <span class="text-mod">(27&ndash;34)</span> 基础<e id=709 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="击中时有概率引发的异常状态，根据基础凋零伤害每秒造成腐蚀伤害，持续 1 秒，可以无限叠加&lt;br/&gt;基础凋零伤害为 0 时，无法造成凋零">凋零</e>伤害<td>86<td>100<td>进阶词缀
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(36&ndash;38)</span> - <span class="text-mod">(44&ndash;46)</span> 点物理伤害<td>86<td>100<td>手杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(123&ndash;125)</span> - <span class="text-mod">(160&ndash;169)</span> 点火焰伤害<td>86<td>100<td>手杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(125&ndash;127)</span> - <span class="text-mod">(165&ndash;167)</span> 点冰冷伤害<td>86<td>100<td>手杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(14&ndash;16)</span> - <span class="text-mod">(276&ndash;278)</span> 点闪电伤害<td>86<td>100<td>手杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(133&ndash;135)</span> - <span class="text-mod">(157&ndash;159)</span> 点腐蚀伤害<td>86<td>100<td>手杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(36&ndash;38)</span> - <span class="text-mod">(44&ndash;46)</span> 点物理伤害<td>86<td>100<td>单手锤
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(123&ndash;125)</span> - <span class="text-mod">(160&ndash;169)</span> 点火焰伤害<td>86<td>100<td>单手锤
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(125&ndash;127)</span> - <span class="text-mod">(165&ndash;167)</span> 点冰冷伤害<td>86<td>100<td>单手锤
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(14&ndash;16)</span> - <span class="text-mod">(276&ndash;278)</span> 点闪电伤害<td>86<td>100<td>单手锤
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(89&ndash;102)</span> - <span class="text-mod">(110&ndash;138)</span> 点火焰伤害<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(89&ndash;102)</span> - <span class="text-mod">(110&ndash;138)</span> 点冰冷伤害<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(11&ndash;12)</span> - <span class="text-mod">(150&ndash;228)</span> 点闪电伤害<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(97&ndash;111)</span> - <span class="text-mod">(113&ndash;129)</span> 点腐蚀伤害<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td>附加 <span class="text-mod">(54&ndash;69)</span> 基础<e id=710 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="击中时有概率引发的异常状态，根据基础点燃伤害每秒造成火焰伤害，持续 4 秒，无法叠加&lt;br/&gt;点燃伤害额外 +30% 加剧效果&lt;br/&gt;基础点燃伤害为 0 时，无法造成点燃">点燃</e>伤害<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td>附加 <span class="text-mod">(27&ndash;34)</span> 基础<e id=709 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="击中时有概率引发的异常状态，根据基础凋零伤害每秒造成腐蚀伤害，持续 1 秒，可以无限叠加&lt;br/&gt;基础凋零伤害为 0 时，无法造成凋零">凋零</e>伤害<td>86<td>100<td>
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(36&ndash;38)</span> - <span class="text-mod">(44&ndash;46)</span> 点物理伤害<td>86<td>100<td>单手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(123&ndash;125)</span> - <span class="text-mod">(160&ndash;169)</span> 点火焰伤害<td>86<td>100<td>单手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(125&ndash;127)</span> - <span class="text-mod">(165&ndash;167)</span> 点冰冷伤害<td>86<td>100<td>单手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(14&ndash;16)</span> - <span class="text-mod">(276&ndash;278)</span> 点闪电伤害<td>86<td>100<td>单手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(133&ndash;135)</span> - <span class="text-mod">(157&ndash;159)</span> 点腐蚀伤害<td>86<td>100<td>单手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(36&ndash;38)</span> - <span class="text-mod">(44&ndash;46)</span> 点物理伤害<td>86<td>100<td>单手斧
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(123&ndash;125)</span> - <span class="text-mod">(160&ndash;169)</span> 点火焰伤害<td>86<td>100<td>单手斧
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(125&ndash;127)</span> - <span class="text-mod">(165&ndash;167)</span> 点冰冷伤害<td>86<td>100<td>单手斧
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(14&ndash;16)</span> - <span class="text-mod">(276&ndash;278)</span> 点闪电伤害<td>86<td>100<td>单手斧
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(36&ndash;38)</span> - <span class="text-mod">(44&ndash;46)</span> 点物理伤害<td>86<td>100<td>匕首
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(123&ndash;125)</span> - <span class="text-mod">(160&ndash;169)</span> 点火焰伤害<td>86<td>100<td>匕首
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(125&ndash;127)</span> - <span class="text-mod">(165&ndash;167)</span> 点冰冷伤害<td>86<td>100<td>匕首
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(14&ndash;16)</span> - <span class="text-mod">(276&ndash;278)</span> 点闪电伤害<td>86<td>100<td>匕首
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(133&ndash;135)</span> - <span class="text-mod">(157&ndash;159)</span> 点腐蚀伤害<td>86<td>100<td>匕首
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(71&ndash;73)</span> - <span class="text-mod">(87&ndash;89)</span> 点物理伤害<td>86<td>100<td>弓
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(152&ndash;154)</span> - <span class="text-mod">(197&ndash;208)</span> 点火焰伤害<td>86<td>100<td>弓
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(154&ndash;156)</span> - <span class="text-mod">(204&ndash;206)</span> 点冰冷伤害<td>86<td>100<td>弓
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(17&ndash;19)</span> - <span class="text-mod">(341&ndash;343)</span> 点闪电伤害<td>86<td>100<td>弓
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(165&ndash;167)</span> - <span class="text-mod">(193&ndash;195)</span> 点腐蚀伤害<td>86<td>100<td>弓
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(71&ndash;73)</span> - <span class="text-mod">(87&ndash;89)</span> 点物理伤害<td>86<td>100<td>双手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(152&ndash;154)</span> - <span class="text-mod">(197&ndash;208)</span> 点火焰伤害<td>86<td>100<td>双手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(154&ndash;156)</span> - <span class="text-mod">(204&ndash;206)</span> 点冰冷伤害<td>86<td>100<td>双手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(17&ndash;19)</span> - <span class="text-mod">(341&ndash;343)</span> 点闪电伤害<td>86<td>100<td>双手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(165&ndash;167)</span> - <span class="text-mod">(193&ndash;195)</span> 点腐蚀伤害<td>86<td>100<td>双手剑
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(71&ndash;73)</span> - <span class="text-mod">(87&ndash;89)</span> 点物理伤害<td>86<td>100<td>双手锤
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(152&ndash;154)</span> - <span class="text-mod">(197&ndash;208)</span> 点火焰伤害<td>86<td>100<td>双手锤
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(154&ndash;156)</span> - <span class="text-mod">(204&ndash;206)</span> 点冰冷伤害<td>86<td>100<td>双手锤
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(17&ndash;19)</span> - <span class="text-mod">(341&ndash;343)</span> 点闪电伤害<td>86<td>100<td>双手锤
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(127&ndash;129)</span> - <span class="text-mod">(164&ndash;174)</span> 点火焰伤害<td>86<td>100<td>锡杖
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(128&ndash;130)</span> - <span class="text-mod">(170&ndash;172)</span> 点冰冷伤害<td>86<td>100<td>锡杖
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(14&ndash;16)</span> - <span class="text-mod">(284&ndash;286)</span> 点闪电伤害<td>86<td>100<td>锡杖
#     <tr data-tier="1"><td>1<td>法术附加 <span class="text-mod">(137&ndash;139)</span> - <span class="text-mod">(161&ndash;163)</span> 点腐蚀伤害<td>86<td>100<td>锡杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(71&ndash;73)</span> - <span class="text-mod">(87&ndash;89)</span> 点物理伤害<td>86<td>100<td>双手斧
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(152&ndash;154)</span> - <span class="text-mod">(197&ndash;208)</span> 点火焰伤害<td>86<td>100<td>双手斧
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(154&ndash;156)</span> - <span class="text-mod">(204&ndash;206)</span> 点冰冷伤害<td>86<td>100<td>双手斧
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(17&ndash;19)</span> - <span class="text-mod">(341&ndash;343)</span> 点闪电伤害<td>86<td>100<td>双手斧
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(71&ndash;73)</span> - <span class="text-mod">(87&ndash;89)</span> 点物理伤害<td>86<td>100<td>武杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(152&ndash;154)</span> - <span class="text-mod">(197&ndash;208)</span> 点火焰伤害<td>86<td>100<td>武杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(154&ndash;156)</span> - <span class="text-mod">(204&ndash;206)</span> 点冰冷伤害<td>86<td>100<td>武杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(17&ndash;19)</span> - <span class="text-mod">(341&ndash;343)</span> 点闪电伤害<td>86<td>100<td>武杖
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(165&ndash;167)</span> - <span class="text-mod">(193&ndash;195)</span> 点腐蚀伤害<td>86<td>100<td>武杖
#     <tr data-tier="1"><td>1<td>攻击和法术附加 <span class="text-mod">(44&ndash;46)</span> - <span class="text-mod">(54&ndash;56)</span> 点物理伤害<td>86<td>100<td>戒指
#     <tr data-tier="1"><td>1<td>攻击和法术附加 <span class="text-mod">(42&ndash;44)</span> - <span class="text-mod">(54&ndash;59)</span> 点火焰伤害<td>86<td>100<td>戒指
#     <tr data-tier="1"><td>1<td>攻击和法术附加 <span class="text-mod">(42&ndash;44)</span> - <span class="text-mod">(56&ndash;58)</span> 点冰冷伤害<td>86<td>100<td>戒指
#     <tr data-tier="1"><td>1<td>攻击和法术附加 <span class="text-mod">(4&ndash;6)</span> - <span class="text-mod">(94&ndash;96)</span> 点闪电伤害<td>86<td>100<td>戒指
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(36&ndash;38)</span> - <span class="text-mod">(44&ndash;46)</span> 点物理伤害<td>86<td>100<td>手枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(123&ndash;125)</span> - <span class="text-mod">(160&ndash;169)</span> 点火焰伤害<td>86<td>100<td>手枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(125&ndash;127)</span> - <span class="text-mod">(165&ndash;167)</span> 点冰冷伤害<td>86<td>100<td>手枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(14&ndash;16)</span> - <span class="text-mod">(276&ndash;278)</span> 点闪电伤害<td>86<td>100<td>手枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(133&ndash;135)</span> - <span class="text-mod">(157&ndash;159)</span> 点腐蚀伤害<td>86<td>100<td>手枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(71&ndash;73)</span> - <span class="text-mod">(87&ndash;89)</span> 点物理伤害<td>86<td>100<td>火枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(152&ndash;154)</span> - <span class="text-mod">(197&ndash;208)</span> 点火焰伤害<td>86<td>100<td>火枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(154&ndash;156)</span> - <span class="text-mod">(204&ndash;206)</span> 点冰冷伤害<td>86<td>100<td>火枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(17&ndash;19)</span> - <span class="text-mod">(341&ndash;343)</span> 点闪电伤害<td>86<td>100<td>火枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(165&ndash;167)</span> - <span class="text-mod">(193&ndash;195)</span> 点腐蚀伤害<td>86<td>100<td>火枪
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(71&ndash;73)</span> - <span class="text-mod">(87&ndash;89)</span> 点物理伤害<td>86<td>100<td>火炮
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(152&ndash;154)</span> - <span class="text-mod">(197&ndash;208)</span> 点火焰伤害<td>86<td>100<td>火炮
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(154&ndash;156)</span> - <span class="text-mod">(204&ndash;206)</span> 点冰冷伤害<td>86<td>100<td>火炮
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(17&ndash;19)</span> - <span class="text-mod">(341&ndash;343)</span> 点闪电伤害<td>86<td>100<td>火炮
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(165&ndash;167)</span> - <span class="text-mod">(193&ndash;195)</span> 点腐蚀伤害<td>86<td>100<td>火炮
#     <tr data-tier="1"><td>1<td>该装备附加 <span class="text-mod">(71&ndash;73)</span> - <span class="text-mod">(87&ndash;89)</span> 点物理伤害<td>86<td>100<td>弩
# ...
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% <e id=137 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="每秒施加加剧值不为 0 时，造成的持续伤害会使目标不断获得加剧值&lt;br/&gt;每点加剧值，使目标额外受到 1% 的持续伤害&lt;br/&gt;加剧值最大为 100 点">加剧</e>效果<td>86<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(87&ndash;120)</span>% 暴击值<td>86<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 攻击与施法速度<br/><span class="text-mod">+(18&ndash;24)</span>% 召唤物攻击与施法速度<td>86<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(44&ndash;60)</span>% 暴击伤害<td>86<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% 收割时间<td>86<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td>每移动 <span class="text-mod">6</span> 米，获得 <span class="text-mod">1</span> 层<e id=159 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="每层偏斜使受到的伤害额外降低 10%，上限 3 层；受击时，消耗所有偏斜层数">偏斜</e><td>100<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td>移动时，额外 <span class="text-mod">+(17&ndash;22)</span>% 闪避值<td>100<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td>开始移动时， 触发 <span class="text-mod">(6&ndash;10)</span> 级迷踪步，间隔 <span class="text-mod">1</span> 秒<td>100<td>100<td>敏捷鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(59&ndash;83)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>冷却回复速度<td>100<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% <e id=137 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="每秒施加加剧值不为 0 时，造成的持续伤害会使目标不断获得加剧值&lt;br/&gt;每点加剧值，使目标额外受到 1% 的持续伤害&lt;br/&gt;加剧值最大为 100 点">加剧</e>效果<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(87&ndash;120)</span>% 暴击值<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 攻击与施法速度<br/><span class="text-mod">+(18&ndash;24)</span>% 召唤物攻击与施法速度<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(44&ndash;60)</span>% 暴击伤害<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% 收割时间<td>86<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td>每移动 <span class="text-mod">6</span> 米，获得 <span class="text-mod">1</span> 层<e id=159 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="每层偏斜使受到的伤害额外降低 10%，上限 3 层；受击时，消耗所有偏斜层数">偏斜</e><td>100<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td>移动时，额外 <span class="text-mod">+(13&ndash;17)</span>% 最大护盾<td>100<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td>开始移动时， 触发 <span class="text-mod">(6&ndash;10)</span> 级迷踪步，间隔 <span class="text-mod">1</span> 秒<td>100<td>100<td>智慧鞋子
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% <e id=137 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="每秒施加加剧值不为 0 时，造成的持续伤害会使目标不断获得加剧值&lt;br/&gt;每点加剧值，使目标额外受到 1% 的持续伤害&lt;br/&gt;加剧值最大为 100 点">加剧</e>效果<td>86<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(44&ndash;60)</span>% 暴击伤害<td>86<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% 收割时间<td>86<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(59&ndash;83)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>冷却回复速度<td>100<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(14&ndash;18)</span>% 力量<td>86<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td>受到持续伤害时，每秒自然回复 <span class="text-mod">(8&ndash;10)</span>% 生命<td>100<td>100<td>力量胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% <e id=137 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="每秒施加加剧值不为 0 时，造成的持续伤害会使目标不断获得加剧值&lt;br/&gt;每点加剧值，使目标额外受到 1% 的持续伤害&lt;br/&gt;加剧值最大为 100 点">加剧</e>效果<td>86<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(44&ndash;60)</span>% 暴击伤害<td>86<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% 收割时间<td>86<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(59&ndash;83)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>冷却回复速度<td>100<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td>每秒自然回复 <span class="text-mod">3</span>% 生命<td>86<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(14&ndash;18)</span>% 敏捷<td>86<td>100<td>敏捷胸甲
#     <tr data-tier="1"><td>1<td>受到持续伤害时，每秒自然回复 <span class="text-mod">(8&ndash;10)</span>% 生命<td>100<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% <e id=137 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="每秒施加加剧值不为 0 时，造成的持续伤害会使目标不断获得加剧值&lt;br/&gt;每点加剧值，使目标额外受到 1% 的持续伤害&lt;br/&gt;加剧值最大为 100 点">加剧</e>效果<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(44&ndash;60)</span>% 暴击伤害<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% 收割时间<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(59&ndash;83)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>冷却回复速度<td>100<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(14&ndash;18)</span>% 智慧<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(43&ndash;60)</span>% 魔力自然回复速度<td>86<td>100<td>智慧胸甲
#     <tr data-tier="1"><td>1<td>额外 <span class="text-mod">+(18&ndash;24)</span>% <e id=102 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="6米内">周围</e>敌人受到的伤害<td>100<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 攻击与施法速度<br/><span class="text-mod">+(18&ndash;24)</span>% 召唤物攻击与施法速度<td>86<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>时间<td>86<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(59&ndash;83)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>冷却回复速度<td>100<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(29&ndash;40)</span>% <e id=762 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="闪电伤害击中时有概率引发的元素异常状态&lt;br/&gt;对具有麻痹的敌人，击中闪电伤害每造成其最大护盾与生命之和的 10% 的伤害，施加一层麻痹&lt;br/&gt;麻痹默认持续时间为 2 秒，每层独立计算&lt;br/&gt;麻痹上限为 10 层，每层麻痹使受到的伤害额外 +5%">麻痹</e>效果<td>100<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(14&ndash;18)</span>% 护甲值<br/><span class="text-mod">+(78&ndash;110)</span> 最大生命<td>86<td>100<td>力量头部
#     <tr data-tier="1"><td>1<td>额外 <span class="text-mod">+(18&ndash;24)</span>% <e id=102 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="6米内">周围</e>敌人受到的伤害<td>100<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 攻击与施法速度<br/><span class="text-mod">+(18&ndash;24)</span>% 召唤物攻击与施法速度<td>86<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>时间<td>86<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(59&ndash;83)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>冷却回复速度<td>100<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(29&ndash;40)</span>% <e id=762 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="闪电伤害击中时有概率引发的元素异常状态&lt;br/&gt;对具有麻痹的敌人，击中闪电伤害每造成其最大护盾与生命之和的 10% 的伤害，施加一层麻痹&lt;br/&gt;麻痹默认持续时间为 2 秒，每层独立计算&lt;br/&gt;麻痹上限为 10 层，每层麻痹使受到的伤害额外 +5%">麻痹</e>效果<td>100<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(14&ndash;18)</span>% 闪避值<br/><span class="text-mod">+(78&ndash;110)</span> 最大生命<td>86<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td>至少拥有 <span class="text-mod">50000</span> 点闪避值时， 额外 <span class="text-mod">-40</span>% 受到的持续伤害<td>100<td>100<td>敏捷头部
#     <tr data-tier="1"><td>1<td>额外 <span class="text-mod">+(18&ndash;24)</span>% <e id=102 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="6米内">周围</e>敌人受到的伤害<td>100<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 攻击与施法速度<br/><span class="text-mod">+(18&ndash;24)</span>% 召唤物攻击与施法速度<td>86<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(36&ndash;50)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>时间<td>86<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(59&ndash;83)</span>% <e id=138 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="对目标造成真实伤害，数值等同于所有持续伤害一定时长的伤害量">收割</e>冷却回复速度<td>100<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(29&ndash;40)</span>% <e id=762 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="闪电伤害击中时有概率引发的元素异常状态&lt;br/&gt;对具有麻痹的敌人，击中闪电伤害每造成其最大护盾与生命之和的 10% 的伤害，施加一层麻痹&lt;br/&gt;麻痹默认持续时间为 2 秒，每层独立计算&lt;br/&gt;麻痹上限为 10 层，每层麻痹使受到的伤害额外 +5%">麻痹</e>效果<td>100<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(12&ndash;16)</span>% 最大护盾<td>86<td>100<td>智慧头部
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(10&ndash;14)</span>% <e id=120 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="包括火焰、冰冷和闪电">元素</e>抗性<td>86<td>100<td>力量盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(10&ndash;14)</span>% <e id=120 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="包括火焰、冰冷和闪电">元素</e>抗性<td>86<td>100<td>敏捷盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+1</span> 战吼技能充能点数上限<td>86<td>100<td>敏捷盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(37&ndash;48)</span>% 战吼技能的效果<td>86<td>100<td>敏捷盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(10&ndash;14)</span>% <e id=120 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="包括火焰、冰冷和闪电">元素</e>抗性<td>86<td>100<td>智慧盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+1</span> 战吼技能充能点数上限<td>86<td>100<td>智慧盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(37&ndash;48)</span>% 战吼技能的效果<td>86<td>100<td>智慧盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 护盾<e id=129 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="角色在 2 秒内未受到伤害，护盾会开启充能；充能期间，每秒回复 20% 最大护盾；充能期间受到伤害就会被打断而停止回复">充能</e>速度<td>86<td>100<td>智慧盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(64&ndash;90)</span>% 魔力自然回复速度<td>86<td>100<td>智慧盾牌
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(87&ndash;120)</span>% 召唤物暴击值<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(44&ndash;60)</span>% 召唤物暴击伤害<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(18&ndash;24)</span>% 攻击与施法速度<br/><span class="text-mod">+(18&ndash;24)</span>% 召唤物攻击与施法速度<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(40&ndash;55)</span>% 召唤物最大生命<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td>魔灵 <span class="text-mod">+(57&ndash;80)</span> 初始<e id=759 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="每 100 点生长值，魔灵召唤物便生长 1 阶。魔灵召唤物初始为 1 阶，最高生长至 5 阶。魔灵召唤物每 8 点生长值，+1% 体型，每生长 1 阶，额外+5% 技能范围，并获得不同加成：&lt;br/&gt;2 阶时，+30% 强化技能几率&lt;br/&gt;3 阶时，强化技能获得增强&lt;br/&gt;4 阶时，激发技能获得增强&lt;br/&gt;5 阶时，额外 +25% 伤害、额外 +10% 技能范围，且移动速度和索敌范围增加。&lt;br/&gt;生长值上限为 1000。">生长值</e><td>100<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(89&ndash;125)</span> 召唤物暴击值<td>100<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td>召唤物 <span class="text-mod">+(19&ndash;26)</span>% 几率造成双倍伤害<td>100<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td>魔灵<e id=140 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="该状态下，获得额外生命回复，不再能够使用技能，也不会被选中为目标；生命回满时失去该状态">重聚</e>时，每秒自然回复 <span class="text-mod">(12&ndash;15)</span>% 生命<td>86<td>100<td>灵戒
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(23&ndash;32)</span>% <e id=764 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="持续 1 秒，持续时间结束时，造成击中腐蚀伤害 60% 的真实伤害；可叠加，上限 99 层，每层独立计算">恶化</e>持续时间<td>100<td>100<td>项链
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(23&ndash;32)</span>% <e id=764 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="持续 1 秒，持续时间结束时，造成击中腐蚀伤害 60% 的真实伤害；可叠加，上限 99 层，每层独立计算">恶化</e>持续时间<td>100<td>100<td>戒指
#     <tr data-tier="1"><td>1<td><span class="text-mod">+(23&ndash;32)</span>% <e id=764 data-bs-toggle="tooltip" data-bs-html="true" data-bs-title="持续 1 秒，持续时间结束时，造成击中腐蚀伤害 60% 的真实伤害；可叠加，上限 99 层，每层独立计算">恶化</e>持续时间<td>100<td>100<td>腰带
#     </tbody>
#     </table>
#   </div>
# </div>
# </div id="T1forge词缀"><div id="打造" class="tab-pane fade"><div   class='card mb-2 '>
#     <div class="card-header">打造</div>
#     <div  class='collapse show'>
#
#     <div class='card-body clearfix'><div>定制非传奇装备上的随机词缀。</div><div class="pt-2">打造功能随主线进度解锁后，即可在主城的【军火商人-吉利】处对非传奇装备进行打造，定制装备上的随机词缀。<br/></div><div class="pt-2">打造时，需要选择指定的词缀库，消耗对应的灰烬和初火燃料，即可在装备上的指定孔位添加或替换词缀库中的词缀。</div><div class="pt-2">词缀库分为：初阶词缀、进阶词缀和至臻词缀。只有珍品装备才能打造至臻词缀，每件装备至多拥有2条进阶词缀和2条至臻词缀。<br/></div><div class="pt-2">此外，还可以使用真理灰烬重新随机装备上所有随机词缀的数值。</div></div>
#
#
#     </div>
# </div></div id="打造"></div class="tab-content">
#     </div>
#     </div>
#
#     <footer class="text-center text-lg-left container mt-2">
#       <div class="card p-4">
#         <div class="row">
#
#           <div class="col-lg-3 col-md-12 mb-4 mb-md-0">
#             <h5 class="text-uppercase">Sites</h5>
#             <ul class="list-unstyled mb-0">
#               <li> <a target="_blank" href="https://poedb.tw/">poedb.tw</a> </li>
#               <li> <a target="_blank" href="https://tlidb.com/">tlidb.com</a> </li>
#               <li> <a target="_blank" href="https://diablo4.cc/">diablo4.cc</a> </li>
#               <li> <a target="_blank" href="https://poe2db.tw/">poe2db.tw</a> </li>
#               <li> <a target="_blank" href="https://paldb.cc/">paldb.cc</a> </li>
#             </ul>
#           </div>
#
#           <div class="col-lg-3 col-md-12 mb-4 mb-md-0">
#             <h5 class="text-uppercase">About Site</h5>
#             <ul class="list-unstyled mb-0">
#               <li><a href="privacy">Privacy</a></li>
#               <li> <a target="_blank" href="https://www.reddit.com/user/chuanhsing">About US</a> </li>
#             </ul>
#           </div>
#
#           <div class="col-lg-3 col-md-6 mb-4 mb-md-0">
#             <h5 class="text-uppercase">Community</h5>
#             <ul class="list-unstyled mb-0">
#             </ul>
#           </div>
#
#         </div>
#       </div>
#       <div class="p-3">
#
#       <span data-i18n="Disclaimer">The site is based on beta testing data, not the final official release. This site is fan-made and not affiliated with XD in any way.</span>
#       </div>
#     </footer>
#
#     <a href="#top" id="toTop"><span class="fas fa-arrow-circle-up fa-3x"></span></a>
#     <div id="consent-box" style="display:none">
#       <button onclick="window.__cmp('showModal');">
#         Update cookie preferences
#       </button>
#     </div>
#
#     <script>
#       if (window["nitroAds"] && window["nitroAds"].loaded) {
#         document.getElementById("consent-box").style.display = window["__tcfapi"]
#           ? ""
#           : "none";
#       } else {
#         document.addEventListener(
#           "nitroAds.loaded",
#           () =>
#             (document.getElementById("consent-box").style.display = window["__tcfapi"]
#               ? ""
#               : "none")
#         );
#       }
#     </script>
#   </body>
# </html>
#
# Found 2 div elements with class 'card-body'. Processing all of them.
# Processing card-body #1...
#   Potentially extracted items from card-body #1. Total items so far: 40
# Processing card-body #2...
#   Card-body #2 contains no <a> tags with class 'p-2' and href.
#
# 成功从所有 'card-body' 区域抓取到数据：

# %%
json_data
# Out:
# '[\n    {\n        "name_cn": "STR Helmet",\n        "name_original": "STR Helmet",\n        "link": "https://tlidb.com/cn/STR_Helmet"\n    },\n    {\n        "name_cn": "DEX Helmet",\n        "name_original": "DEX Helmet",\n        "link": "https://tlidb.com/cn/DEX_Helmet"\n    },\n    {\n        "name_cn": "INT Helmet",\n        "name_original": "INT Helmet",\n        "link": "https://tlidb.com/cn/INT_Helmet"\n    },\n    {\n        "name_cn": "STR Chest Armor",\n        "name_original": "STR Chest Armor",\n        "link": "https://tlidb.com/cn/STR_Chest_Armor"\n    },\n    {\n        "name_cn": "DEX Chest Armor",\n        "name_original": "DEX Chest Armor",\n        "link": "https://tlidb.com/cn/DEX_Chest_Armor"\n    },\n    {\n        "name_cn": "INT Chest Armor",\n        "name_original": "INT Chest Armor",\n        "link": "https://tlidb.com/cn/INT_Chest_Armor"\n    },\n    {\n        "name_cn": "STR Gloves",\n        "name_original": "STR Gloves",\n        "link": "https://tlidb.com/cn/STR_Gloves"\n    },\n    {\n        "name_cn": "DEX Gloves",\n        "name_original": "DEX Gloves",\n        "link": "https://tlidb.com/cn/DEX_Gloves"\n    },\n    {\n        "name_cn": "INT Gloves",\n        "name_original": "INT Gloves",\n        "link": "https://tlidb.com/cn/INT_Gloves"\n    },\n    {\n        "name_cn": "STR Boots",\n        "name_original": "STR Boots",\n        "link": "https://tlidb.com/cn/STR_Boots"\n    },\n    {\n        "name_cn": "DEX Boots",\n        "name_original": "DEX Boots",\n        "link": "https://tlidb.com/cn/DEX_Boots"\n    },\n    {\n        "name_cn": "INT Boots",\n        "name_original": "INT Boots",\n        "link": "https://tlidb.com/cn/INT_Boots"\n    },\n    {\n        "name_cn": "Claw",\n        "name_original": "Claw",\n        "link": "https://tlidb.com/cn/Claw"\n    },\n    {\n        "name_cn": "Dagger",\n        "name_original": "Dagger",\n        "link": "https://tlidb.com/cn/Dagger"\n    },\n    {\n        "name_cn": "One-Handed Sword",\n        "name_original": "One-Handed Sword",\n        "link": "https://tlidb.com/cn/One-Handed_Sword"\n    },\n    {\n        "name_cn": "One-Handed Hammer",\n        "name_original": "One-Handed Hammer",\n        "link": "https://tlidb.com/cn/One-Handed_Hammer"\n    },\n    {\n        "name_cn": "One-Handed Axe",\n        "name_original": "One-Handed Axe",\n        "link": "https://tlidb.com/cn/One-Handed_Axe"\n    },\n    {\n        "name_cn": "Wand",\n        "name_original": "Wand",\n        "link": "https://tlidb.com/cn/Wand"\n    },\n    {\n        "name_cn": "Rod",\n        "name_original": "Rod",\n        "link": "https://tlidb.com/cn/Rod"\n    },\n    {\n        "name_cn": "Scepter",\n        "name_original": "Scepter",\n        "link": "https://tlidb.com/cn/Scepter"\n    },\n    {\n        "name_cn": "Cane",\n        "name_original": "Cane",\n        "link": "https://tlidb.com/cn/Cane"\n    },\n    {\n        "name_cn": "Pistol",\n        "name_original": "Pistol",\n        "link": "https://tlidb.com/cn/Pistol"\n    },\n    {\n        "name_cn": "Two-Handed Sword",\n        "name_original": "Two-Handed Sword",\n        "link": "https://tlidb.com/cn/Two-Handed_Sword"\n    },\n    {\n        "name_cn": "Two-Handed Hammer",\n        "name_original": "Two-Handed Hammer",\n        "link": "https://tlidb.com/cn/Two-Handed_Hammer"\n    },\n    {\n        "name_cn": "Two-Handed Axe",\n        "name_original": "Two-Handed Axe",\n        "link": "https://tlidb.com/cn/Two-Handed_Axe"\n    },\n    {\n        "name_cn": "Tin Staff",\n        "name_original": "Tin Staff",\n        "link": "https://tlidb.com/cn/Tin_Staff"\n    },\n    {\n        "name_cn": "Cudgel",\n        "name_original": "Cudgel",\n        "link": "https://tlidb.com/cn/Cudgel"\n    },\n    {\n        "name_cn": "Bow",\n        "name_original": "Bow",\n        "link": "https://tlidb.com/cn/Bow"\n    },\n    {\n        "name_cn": "Crossbow",\n        "name_original": "Crossbow",\n      ...

# %% [markdown]
# ## 抓取具体词条
#
# 基础词条、前后缀、解梦词条
