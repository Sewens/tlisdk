# %% [markdown]
# # 解析装备页面
#
# 包含基础装备，传奇装备，英雄追忆以及装备词条。
#
# 词条：
# * 基础词条
# * 侵蚀词条
# * 解梦词条

# %%
import json
from bs4 import BeautifulSoup

# %%
import os
import pandas as pd

# %%
import re

# %%
def save_json(obj, fpath):
    if not os.path.isdir('../data/json/'):
        os.mkdir('../data/json/')
    with open(os.path.join('../data/json/',fpath),'w',encoding='utf-8') as file:
        json.dump(obj,file,ensure_ascii=False)

# %% [markdown]
# ## 1. 英雄追忆页面
#
# 包括主要天赋，小型、中型天赋、传奇中型天赋和新神天赋
#
# https://tlidb.com/cn/Talent

# %%
memory_key_map = {
    'Memory_of_Origin':'Memory_of_Origin',
    'Memory_of_Discipline':'Memory_of_Discipline',
    'Memory_of_Progress':'Memory_of_Progress',
}

# %%
memory_attrs_key_map = {
    'base_attrs':'基础属性',
    'fix_attrs':'固有词缀'
}

# %%
def unpack_nested(nodes,):
    nodes += ['']
    for hdx in range(0,len(nodes)-1):
        nodes[hdx] = nodes[hdx].replace(nodes[hdx+1],'')
    nodes.pop()
    return nodes

# %%
def parse_nested_head(node):
    headers = [i.text.strip() for i in node.find('thead').find('tr').find_all('th')]
    headers = unpack_nested(headers)
    return headers

# %%
def parse_nested_body(node):
    bodies = unpack_nested([i.text.strip() for i in BeautifulSoup(node,'html.parser').find_all('td')])
    return bodies

# %%
memory_data = {}
for memo_name in memory_key_map:
    
    html_code = open(f'../data/site/cn/{memo_name}.html').read()
    
    soup = BeautifulSoup(html_code, 'html.parser')
    
    memo_node = dict()
    
    for attr_key in memory_attrs_key_map:
        print(memo_name, attr_key, memory_attrs_key_map[attr_key])
        
        soup_tb = soup.find('div',id=memory_attrs_key_map[attr_key])
        
        # 获取表头
        headers = parse_nested_head(soup_tb)
        
        bodies = [i for i in str(soup_tb.find('tbody').find('tr')).replace('</tr>','').replace('</td>','').replace('<tr>','\n').split('\n') 
                              if i!='']
        
        # 初始化结果列表
        data = []
        
        # 遍历每一行数据
        for row in bodies:
            cells = parse_nested_body(row)
            row_data = {k:v for k,v in zip(headers,cells)}
            
            # 将字典添加到结果列表中
            data.append(row_data)
        
        memo_node[attr_key] = data

    memory_data[memo_name] = memo_node
# Out:
# Memory_of_Origin base_attrs 基础属性
# Memory_of_Origin fix_attrs 固有词缀
# Memory_of_Discipline base_attrs 基础属性
# Memory_of_Discipline fix_attrs 固有词缀
# Memory_of_Progress base_attrs 基础属性
# Memory_of_Progress fix_attrs 固有词缀

# %%
save_json(memory_data, 'memory.json')

# %% [markdown]
# ## 2. 装备界面

# %%
base_equip_nodes = {}

# %%
# 使用BeautifulSoup解析HTML
soup = BeautifulSoup(open('../data/site/cn/Craft.html'), 'html.parser')

# 找到id为MainTalentNode的div标签
profession_node = soup.find(name='div', attrs={"id":talent_key_map["Profession"]})

for col_node in profession_node.find_all(name='div',attrs={"class":"col"}):
    
    href = col_node.find('a').attrs['href']
    text_name = col_node.find(name='a').text
    main_attrs = re.findall(r'主要属性：(\w+)',str(col_node))
    main_tag = col_node.find('richtext').contents[0].split('、') if col_node.find('richtext').contents else []
    
    talent_nodes[href] = {'talent_name':text_name,
                         'talent_main_attribute':main_attrs,
                         'talent_tags':main_tag,
                         'main_talent_lst':[],
                         'mini_talent_lst':[],
                         'mid_talent_lst':[],
                          'legend_mid_talent_lst':[]
                         }

# %%
talent_nodes
# Out:
# {'God_of_Might': {'talent_name': '巨力之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['攻击', '火焰'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Goddess_of_Hunting': {'talent_name': '狩猎之神',
#   'talent_main_attribute': ['敏捷'],
#   'talent_tags': ['速度', '闪电'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Goddess_of_Knowledge': {'talent_name': '知识之神',
#   'talent_main_attribute': ['智慧'],
#   'talent_tags': ['法术', '冰冷'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'God_of_War': {'talent_name': '征战之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['几率', '物理'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Goddess_of_Deception': {'talent_name': '欺诈之神',
#   'talent_main_attribute': ['敏捷'],
#   'talent_tags': ['持续', '腐蚀'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'God_of_Machines': {'talent_name': '机械之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['召唤', '哨卫'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'The_Brave': {'talent_name': '勇者',
#   'talent_main_attribute': [],
#   'talent_tags': ['单手武器', '护甲'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Onslaughter': {'talent_name': '猛袭者',
#   'talent_main_attribute': [],
#   'talent_tags': ['双手武器', '生命'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Warlord': {'talent_name': '督军',
#   'talent_main_attribute': [],
#   'talent_tags': ['火焰', '范围'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Marksman': {'talent_name': '神射手',
#   'talent_main_attribute': [],
#   'talent_tags': ['投射物', '闪避'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Bladerunner': {'talent_name': '刀锋行者',
#   'talent_main_attribute': [],
#   'talent_tags': ['闪电', '攻击速度'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Druid': {'talent_name': '德鲁伊',
#   'talent_main_attribute': [],
#   'talent_tags': ['施法速度', '返还'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Magister': {'talent_name': '魔导师',
#   'talent_main_attribute': [],
#   'talent_tags': ['法术', '护盾'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Arcanist': {'talent_name': '秘术师',
#   'talent_main_attribute': [],
#   'talent_tags': ['冰冷', '魔力'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Elementalist': {'talent_name': '元素师',
#   'talent_main_attribute': [],
#   'talent_tags': ['引导', '元素'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Shadowdancer': {'talent_name': '影舞者',
#   'talent_main_attribute': [],
#   'talent_tags': ['物理', '触发'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Ronin': {'talent_name': '神行武士',
#   'talent_main_attribute': [],
#   'talent_tags': ['近战', '格挡'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Ranger': {'talent_name': '游侠',
#   'talent_main_attribute': [],
#   'talent_tags': ['暴击', '距离'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Shadowmaster': {'talent_name': '驭影者',
#   'talent_main_attribute': [],
#   'talent_tags': ['腐蚀', '封印'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Psychic': {'talent_name': '异能者',
#   'talent_main_attribute': [],
#   'talent_tags': ['持续', '负面效果'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Warlock': {'talent_name': '暗影术士',
#   'talent_main_attribute': [],
#   'talent_tags': ['技能', '异常'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Machinist': {'talent_name': '机械师',
#   'talent_main_attribute': [],
#   'talent_tags': ['智械', '哨卫'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Steel_Vanguard': {'talent_name': '钢铁先锋',
#   'talent_main_attribute': [],
#   'talent_tags': ['增益效果', '抗性'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Alchemist': {'talent_name': '炼金术士',
#   'talent_main_attribute': [],
#   'talent_tags': ['魔灵', '回复'],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'New_God': {'talent_name': '新神',
#   'talent_main_attribute': [],
#   'talent_tags': [],
#   'main_talent_lst': [],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []}}

# %% [markdown]
# ### 1.2 解析主要天赋

# %%
# 找到id为MainTalentNode的div标签
main_talent_node = soup.find(name='div', attrs={"id":talent_key_map["MainTalentNode"]})

for col_node in main_talent_node.find_all(name='div',attrs={"class":"col"}):
    main_talent = {
                'talent_name':'',
        'talent_id':'',
              'talent_description':'',
                'talent_type':'main'
                  }
    
    tid = col_node.find('img').attrs['src'].split('\\')[1].removesuffix('.webp')
    
    name = col_node.find_all('span')[0].text
    talent_key = col_node.find('a').attrs['href']
    desc = col_node.text
    main_talent['talent_name'] = name
    main_talent['talent_description'] = desc
    main_talent['talent_id'] = tid
    
    talent_nodes[talent_key]['main_talent_lst'].append(main_talent)

# %%
talent_nodes
# Out:
# {'God_of_Might': {'talent_name': '巨力之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['攻击', '火焰'],
#   'main_talent_lst': [{'talent_name': '淘汰',
#     'talent_id': 'UI_CoreTalentIcon_taotai_Icon_128',
#     'talent_description': '淘汰巨力之神攻击击中时，淘汰生命值低于 18% 的敌人',
#     'talent_type': 'main'},
#    {'talent_name': '燃尽',
#     'talent_id': 'UI_CoreTalentIcon_ranjin_Icon_128',
#     'talent_description': '燃尽巨力之神额外 +24% 火焰伤害重创敌人时，使敌人 +20% 火焰抗性，持续 1 秒',
#     'talent_type': 'main'},
#    {'talent_name': '坚韧',
#     'talent_id': 'UI_CoreTalentIcon_jianren_Icon_128',
#     'talent_description': '坚韧巨力之神击中敌人时，+100% 几率获得 1 层坚韧祝福+1 坚韧祝福层数上限',
#     'talent_type': 'main'},
#    {'talent_name': '势大力沉',
#     'talent_id': 'UI_CoreTalentIcon_shidalichen_Icon_128',
#     'talent_description': '势大力沉巨力之神-10% 攻击速度额外 +30% 攻击伤害额外 +30% 攻击造成的异常伤害',
#     'talent_type': 'main'},
#    {'talent_name': '火上浇油',
#     'talent_id': 'UI_CoreTalentIcon_huoshangjiaoyou_Icon_128',
#     'talent_description': '火上浇油巨力之神伤害无视敌人火焰抗性',
#     'talent_type': 'main'},
#    {'talent_name': '燎原烈火',
#     'talent_id': 'UI_CoreTalentIcon_liaoyuanliehuo_Icon_128',
#     'talent_description': '燎原烈火巨力之神额外 +20% 火焰持续伤害造成火焰伤害时，施加 10 加剧值，冷却时间 0.1 秒',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Goddess_of_Hunting': {'talent_name': '狩猎之神',
#   'talent_main_attribute': ['敏捷'],
#   'talent_tags': ['速度', '闪电'],
#   'main_talent_lst': [{'talent_name': '敏锐',
#     'talent_id': 'UI_CoreTalentIcon_minrui_Icon_128',
#     'talent_description': '敏锐狩猎之神击中敌人时，+100% 概率获得 1 层灵动祝福+1 灵动祝福层数上限',
#     'talent_type': 'main'},
#    {'talent_name': '感电',
#     'talent_id': 'UI_CoreTalentIcon_mabi_Icon_128',
#     'talent_description': '感电狩猎之神如果在 0.2 秒内造成过闪电伤害，额外 +20% 闪电伤害',
#     'talent_type': 'main'},
#    {'talent_name': '闪烁',
#     'talent_id': 'UI_CoreTalentIcon_shanshuo_Icon_128',
#     'talent_description': '闪烁狩猎之神额外 +50% 位移技能冷却回复速度额外 +25% 位移技能攻击与施法速度',
#     'talent_type': 'main'},
#    {'talent_name': '行色匆匆',
#     'talent_id': 'UI_CoreTalentIcon_xingsecongcong_Icon_128',
#     'talent_description': '行色匆匆狩猎之神如果最近移动了超过 5 米，额外 +30% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '世事无常',
#     'talent_id': 'UI_CoreTalentIcon_shishiwuchang_Icon_128',
#     'talent_description': '世事无常狩猎之神额外 -40% 最小伤害额外 +40% 最大伤害',
#     'talent_type': 'main'},
#    {'talent_name': '灵光一现',
#     'talent_id': 'UI_CoreTalentIcon_lingguangyixian_Icon_128',
#     'talent_description': '灵光一现狩猎之神对法术伤害，闪避值不再默认额外降低额外 +20% 闪避值',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Goddess_of_Knowledge': {'talent_name': '知识之神',
#   'talent_main_attribute': ['智慧'],
#   'talent_tags': ['法术', '冰冷'],
#   'main_talent_lst': [{'talent_name': '灯塔',
#     'talent_id': 'UI_CoreTalentIcon_dengta_Icon_128',
#     'talent_description': '灯塔知识之神法术迸发上限 +2',
#     'talent_type': 'main'},
#    {'talent_name': '苦寒',
#     'talent_id': 'UI_CoreTalentIcon_kuhan_Icon_128',
#     'talent_description': '苦寒知识之神击中时，+100% 几率获得 1 层聚能祝福+1 聚能祝福层数上限',
#     'talent_type': 'main'},
#    {'talent_name': '凛冬',
#     'talent_id': 'UI_CoreTalentIcon_yongdongzhizhou_Icon_128',
#     'talent_description': '凛冬知识之神敌人每有 2 点冰结值，对其额外 +1% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '别具慧眼',
#     'talent_id': 'UI_CoreTalentIcon_biejuhuiyan_Icon_128',
#     'talent_description': '别具慧眼知识之神额外 +30% 法术伤害额外 +25% 技能消耗',
#     'talent_type': 'main'},
#    {'talent_name': '炙手可热',
#     'talent_id': 'UI_CoreTalentIcon_zhishoukere_Icon_128',
#     'talent_description': '炙手可热知识之神免疫冰结额外 +20% 冰冷和火焰伤害',
#     'talent_type': 'main'},
#    {'talent_name': '养精蓄锐',
#     'talent_id': 'UI_CoreTalentIcon_yangjingxurui_Icon_128',
#     'talent_description': '养精蓄锐知识之神每消耗 6% 魔力，获得 1 层聚能祝福，间隔 0.3 秒额外 -50% 聚能祝福持续时间聚能祝福达到上限时，额外 +25% 施法速度',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'God_of_War': {'talent_name': '征战之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['几率', '物理'],
#   'main_talent_lst': [{'talent_name': '凝聚',
#     'talent_id': 'UI_CoreTalentIcon_ningju_Icon_128',
#     'talent_description': '凝聚征战之神每隔 1 秒，下一次核心技能额外 +50% 暴击值',
#     'talent_type': 'main'},
#    {'talent_name': '残暴',
#     'talent_id': 'UI_CoreTalentIcon_canbao_Icon_128',
#     'talent_description': '残暴征战之神额外 +25% 物理伤害每 5 等级，额外 -1% 元素伤害',
#     'talent_type': 'main'},
#    {'talent_name': '坚强',
#     'talent_id': 'UI_CoreTalentIcon_jianqiang_Icon_128',
#     'talent_description': '坚强征战之神受到巨额伤害后，保留1点生命，并且免疫持续伤害1秒，该效果具有 8 秒冷却时间',
#     'talent_type': 'main'},
#    {'talent_name': '自主升级',
#     'talent_id': 'UI_CoreTalentIcon_zizhushengji_Icon_128',
#     'talent_description': '自主升级征战之神+20% 攻击与法术格挡率最近每格挡 1 次，+5% 攻击与法术格挡率，至多叠加 5 层',
#     'talent_type': 'main'},
#    {'talent_name': '迎头痛击',
#     'talent_id': 'UI_CoreTalentIcon_yingtoutongji_Icon_128',
#     'talent_description': '迎头痛击征战之神额外 +100% 暴击造成的创伤伤害',
#     'talent_type': 'main'},
#    {'talent_name': '无边战意',
#     'talent_id': 'UI_CoreTalentIcon_wubianzhanyi_Icon_128',
#     'talent_description': '无边战意征战之神拥有战意+12% 战意效果',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Goddess_of_Deception': {'talent_name': '欺诈之神',
#   'talent_main_attribute': ['敏捷'],
#   'talent_tags': ['持续', '腐蚀'],
#   'main_talent_lst': [{'talent_name': '瘟疫',
#     'talent_id': 'UI_CoreTalentIcon_wenyi_Icon_128',
#     'talent_description': '瘟疫欺诈之神持续伤害有 50% 几率扩散至周围目标+30% 持续伤害持续时间',
#     'talent_type': 'main'},
#    {'talent_name': '混入',
#     'talent_id': 'UI_CoreTalentIcon_hunru_Icon_128',
#     'talent_description': '混入欺诈之神99% 元素伤害转化为腐蚀伤害对敌人造成伤害时，+99% 几率使目标瘫痪',
#     'talent_type': 'main'},
#    {'talent_name': '疾徐',
#     'talent_id': 'UI_CoreTalentIcon_jixu_Icon_128',
#     'talent_description': '疾徐欺诈之神施加持续伤害后 2 秒内，额外 +25% 持续伤害，该效果不可叠加',
#     'talent_type': 'main'},
#    {'talent_name': '潜移默化',
#     'talent_id': 'UI_CoreTalentIcon_qianyimohua_Icon_128',
#     'talent_description': '潜移默化欺诈之神迷踪获得额外效果：额外 +25% 持续伤害',
#     'talent_type': 'main'},
#    {'talent_name': '禁忌力量',
#     'talent_id': 'UI_CoreTalentIcon_jinjililiang_Icon_128',
#     'talent_description': '禁忌力量欺诈之神额外 +40% 腐蚀伤害-15% 元素抗性',
#     'talent_type': 'main'},
#    {'talent_name': '饮鸩止渴',
#     'talent_id': 'UI_CoreTalentIcon_yinzhenzhike_Icon_128',
#     'talent_description': '饮鸩止渴欺诈之神+25% 受伤缓冲生命濒危时，额外 -15% 受到的伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'God_of_Machines': {'talent_name': '机械之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['召唤', '哨卫'],
#   'main_talent_lst': [{'talent_name': '号令',
#     'talent_id': 'UI_CoreTalentIcon_haoling_Icon_128',
#     'talent_description': '号令机械之神额外 +20% 召唤物伤害额外 +100% 召唤技能施法速度',
#     'talent_type': 'main'},
#    {'talent_name': '哨兵',
#     'talent_id': 'UI_CoreTalentIcon_shaobing_Icon_128',
#     'talent_description': '哨兵机械之神+1 哨卫数量上限放置哨卫的技能额外 +100% 施法速度',
#     'talent_type': 'main'},
#    {'talent_name': '龟缩',
#     'talent_id': 'UI_CoreTalentIcon_guisuo_Icon_128',
#     'talent_description': '龟缩机械之神受到伤害时， +50% 几率获得屏障',
#     'talent_type': 'main'},
#    {'talent_name': '强力护卫',
#     'talent_id': 'UI_CoreTalentIcon_qianglihuwei_Icon_128',
#     'talent_description': '强力护卫机械之神+2 召唤召唤物的技能等级每秒统御值增加 4 点魔灵 +40 初始生长值',
#     'talent_type': 'main'},
#    {'talent_name': '过度改装',
#     'talent_id': 'UI_CoreTalentIcon_guodugaizhuang_Icon_128',
#     'talent_description': '过度改装机械之神额外 +30% 哨卫伤害，额外 -50% 非哨卫主动技能伤害',
#     'talent_type': 'main'},
#    {'talent_name': '同构武装',
#     'talent_id': 'UI_CoreTalentIcon_tonggouwuzhuang_Icon_128',
#     'talent_description': '同构武装机械之神召唤物获得主手武器的加成额外 +15% 召唤物攻击和施法速度',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'The_Brave': {'talent_name': '勇者',
#   'talent_main_attribute': [],
#   'talent_tags': ['单手武器', '护甲'],
#   'main_talent_lst': [{'talent_name': '审判',
#     'talent_id': 'UI_CoreTalentIcon_shenpan_Icon_128',
#     'talent_description': '审判勇者攻击击中时， +100% 几率造成瘫痪对瘫痪敌人， 额外 +20% 暴击伤害',
#     'talent_type': 'main'},
#    {'talent_name': '坚毅',
#     'talent_id': 'UI_CoreTalentIcon_jianyi_Icon_128',
#     'talent_description': '坚毅勇者每有 1 层坚韧祝福， 额外 +4% 护甲值',
#     'talent_type': 'main'},
#    {'talent_name': '合力',
#     'talent_id': 'UI_CoreTalentIcon_heli_Icon_128',
#     'talent_description': '合力勇者双持时，副手武器不参与攻击附加 100% 副手武器伤害至主手武器',
#     'talent_type': 'main'},
#    {'talent_name': '势均力敌',
#     'talent_id': 'UI_CoreTalentIcon_shijunlidi_Icon_128',
#     'talent_description': '势均力敌勇者双持时，额外 +30% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '灰烬装甲',
#     'talent_id': 'UI_CoreTalentIcon_huijinzhuangjia_Icon_128',
#     'talent_description': '灰烬装甲勇者对非物理伤害，+25% 护甲有效率',
#     'talent_type': 'main'},
#    {'talent_name': '大象无形',
#     'talent_id': 'UI_CoreTalentIcon_daxiangwuxing_Icon_128',
#     'talent_description': '大象无形勇者战吼立即释放额外 +25% 近战伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Onslaughter': {'talent_name': '猛袭者',
#   'talent_main_attribute': [],
#   'talent_tags': ['双手武器', '生命'],
#   'main_talent_lst': [{'talent_name': '借势',
#     'talent_id': 'UI_CoreTalentIcon_jieshi_Icon_128',
#     'talent_description': '借势猛袭者每隔 0.5 秒，下一次核心技能额外 +30% 攻击伤害；击败时，刷新此间隔',
#     'talent_type': 'main'},
#    {'talent_name': '秘法',
#     'talent_id': 'UI_CoreTalentIcon_mifa_Icon_128',
#     'talent_description': '秘法猛袭者魔力消耗的 100% 转换为生命消耗额外 +20% 最大生命',
#     'talent_type': 'main'},
#    {'talent_name': '舍命',
#     'talent_id': 'UI_CoreTalentIcon_sheming_Icon_128',
#     'talent_description': '舍命猛袭者坚韧祝福的基础效果转换为：额外 +8% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '善始善终',
#     'talent_id': 'UI_CoreTalentIcon_shanshishanzhong_Icon_128',
#     'talent_description': '善始善终猛袭者生命濒危时，额外 +30% 攻击伤害',
#     'talent_type': 'main'},
#    {'talent_name': '生命通道',
#     'talent_id': 'UI_CoreTalentIcon_shengmingtongdao_Icon_128',
#     'talent_description': '生命通道猛袭者生命返还量翻倍生命返还仅在生命小于 50% 时生效',
#     'talent_type': 'main'},
#    {'talent_name': '生存意志',
#     'talent_id': 'UI_CoreTalentIcon_shengcunyizhi_Icon_128',
#     'talent_description': '生存意志猛袭者生命濒危时，额外 +100% 生命自然回复速度受击后 2 秒内，每秒自然回复 1% 生命，最多叠加 15 层',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Warlord': {'talent_name': '督军',
#   'talent_main_attribute': [],
#   'talent_tags': ['火焰', '范围'],
#   'main_talent_lst': [{'talent_name': '野火',
#     'talent_id': 'UI_CoreTalentIcon_yehuo_Icon_128',
#     'talent_description': '野火督军对生命濒危敌人造成的火焰伤害额外 +100%召唤物对生命濒危敌人造成的火焰伤害额外 +100%',
#     'talent_type': 'main'},
#    {'talent_name': '清扫',
#     'talent_id': 'UI_CoreTalentIcon_qingsao_Icon_128',
#     'talent_description': '清扫督军最近每击败 1 个敌人，+10% 技能范围，至多 100%',
#     'talent_type': 'main'},
#    {'talent_name': '磐石',
#     'talent_id': 'UI_CoreTalentIcon_jianruopanshi_Icon_128',
#     'talent_description': '磐石督军每有 1 层坚韧祝福， +3% 火焰穿透',
#     'talent_type': 'main'},
#    {'talent_name': '真实之焰',
#     'talent_id': 'UI_CoreTalentIcon_zhenshizhiyan_Icon_128',
#     'talent_description': '真实之焰督军敌人被点燃时，加剧对其受到的持续伤害额外加成的 60% 同样作用于你的击中火焰伤害',
#     'talent_type': 'main'},
#    {'talent_name': '聚能之击',
#     'talent_id': 'UI_CoreTalentIcon_junengzhiji_Icon_128',
#     'talent_description': '聚能之击督军范围技能对中心敌人造成至多 32% 额外伤害召唤物的范围技能对中心敌人造成至多 32% 额外伤害',
#     'talent_type': 'main'},
#    {'talent_name': '星星之火',
#     'talent_id': 'UI_CoreTalentIcon_xinhuo_Icon_128',
#     'talent_description': '星星之火督军+1 点燃上限+30% 点燃持续时间',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Marksman': {'talent_name': '神射手',
#   'talent_main_attribute': [],
#   'talent_tags': ['投射物', '闪避'],
#   'main_talent_lst': [{'talent_name': '狂风',
#     'talent_id': 'UI_CoreTalentIcon_kuangfeng_Icon_128',
#     'talent_description': '狂风神射手对投射物速度加成的 40% 同样作用于对伤害的额外加成',
#     'talent_type': 'main'},
#    {'talent_name': '心流',
#     'talent_id': 'UI_CoreTalentIcon_xinliu_Icon_128',
#     'talent_description': '心流神射手每 0.3 秒，额外 +5% 伤害，该效果最多叠加 8 层，并且在受击后重置',
#     'talent_type': 'main'},
#    {'talent_name': '亢奋',
#     'talent_id': 'UI_CoreTalentIcon_kangfen_Icon_128',
#     'talent_description': '亢奋神射手每有 1 层灵动祝福，额外 +4% 闪避值',
#     'talent_type': 'main'},
#    {'talent_name': '一箭三雕',
#     'talent_id': 'UI_CoreTalentIcon_yijiansandiao_Icon_128',
#     'talent_description': '一箭三雕神射手+2 投射物数量+2 抛射投射物分裂数量额外 +10% 投射物伤害',
#     'talent_type': 'main'},
#    {'talent_name': '逃脱大师',
#     'talent_id': 'UI_CoreTalentIcon_taotuodashi_Icon_128',
#     'talent_description': '逃脱大师神射手每隔 0.5 秒，获得 1 层偏斜闪避时，获得 1 层偏斜',
#     'talent_type': 'main'},
#    {'talent_name': '抵近射击',
#     'talent_id': 'UI_CoreTalentIcon_dijinsheji_Icon_128',
#     'talent_description': '抵近射击神射手投射物对近处的敌人至多额外 +35% 伤害，随距离递减',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Bladerunner': {'talent_name': '刀锋行者',
#   'talent_main_attribute': [],
#   'talent_tags': ['闪电', '攻击速度'],
#   'main_talent_lst': [{'talent_name': '导电',
#     'talent_id': 'UI_CoreTalentIcon_daodian_Icon_128',
#     'talent_description': '导电刀锋行者麻痹基础效果转换为：额外 +8% 受到的伤害额外施加 2 层麻痹',
#     'talent_type': 'main'},
#    {'talent_name': '入静',
#     'talent_id': 'UI_CoreTalentIcon_rujing_Icon_128',
#     'talent_description': '入静刀锋行者停止移动后的第一次非引导攻击额外 +35% 攻击速度；该次攻击为连续攻击时，增益延续至连续攻击结束玩家静止时，额外 +35% 召唤物攻击与施法速度',
#     'talent_type': 'main'},
#    {'talent_name': '跃迁',
#     'talent_id': 'UI_CoreTalentIcon_yueqian_Icon_128',
#     'talent_description': '跃迁刀锋行者释放技能时，50% 几率使该次技能额外 +16% 伤害释放技能时，25% 几率使该次技能额外 +32% 伤害释放技能时，10% 几率使该次技能额外 +80% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '奇妙角度',
#     'talent_id': 'UI_CoreTalentIcon_qimiaojiaodu_Icon_128',
#     'talent_description': '奇妙角度刀锋行者对麻痹的敌人，你与召唤物造成的伤害幸运',
#     'talent_type': 'main'},
#    {'talent_name': '势如破竹',
#     'talent_id': 'UI_CoreTalentIcon_shirupozhu_Icon_128',
#     'talent_description': '势如破竹刀锋行者连续攻击伤害递增 55%召唤物连续攻击伤害递增 55%',
#     'talent_type': 'main'},
#    {'talent_name': '伺机而动',
#     'talent_id': 'UI_CoreTalentIcon_sijierdong_Icon_128',
#     'talent_description': '伺机而动刀锋行者每隔 4 秒，消耗所有灵动祝福，每消耗 1 层，在接下来的 4 秒内额外 +4% 伤害使用技能时，获得灵动祝福',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Druid': {'talent_name': '德鲁伊',
#   'talent_main_attribute': [],
#   'talent_tags': ['施法速度', '返还'],
#   'main_talent_lst': [{'talent_name': '栽培',
#     'talent_id': 'UI_CoreTalentIcon_zaipei_Icon_128',
#     'talent_description': '栽培德鲁伊最近每使用一次技能，+3% 施法速度，至多叠加 15 层',
#     'talent_type': 'main'},
#    {'talent_name': '稳定',
#     'talent_id': 'UI_CoreTalentIcon_wending_Icon_128',
#     'talent_description': '稳定德鲁伊返还生命时，回复 5% 生命返还护盾时，回复 5% 护盾',
#     'talent_type': 'main'},
#    {'talent_name': '沉着',
#     'talent_id': 'UI_CoreTalentIcon_chenzhuo_Icon_128',
#     'talent_description': '沉着德鲁伊生命濒危并且低护盾时，额外 -50% 受到的伤害生命健康时，额外 +25% 受到的伤害',
#     'talent_type': 'main'},
#    {'talent_name': '似曾相识',
#     'talent_id': 'UI_CoreTalentIcon_sicengxiangshi_Icon_128',
#     'talent_description': '似曾相识德鲁伊使用核心法术技能时，+30% 几率额外触发一次',
#     'talent_type': 'main'},
#    {'talent_name': '脱胎换骨',
#     'talent_id': 'UI_CoreTalentIcon_tuotaihuangu_Icon_128',
#     'talent_description': '脱胎换骨德鲁伊50% 生命返还与护盾返还转换为持续回复额外 -50% 返还间隔',
#     'talent_type': 'main'},
#    {'talent_name': '无迹可寻',
#     'talent_id': 'UI_CoreTalentIcon_wujikexun_Icon_128',
#     'talent_description': '无迹可寻德鲁伊灵动祝福基础效果转换为：+8% 施法速度',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Magister': {'talent_name': '魔导师',
#   'talent_main_attribute': [],
#   'talent_tags': ['法术', '护盾'],
#   'main_talent_lst': [{'talent_name': '积聚',
#     'talent_id': 'UI_CoreTalentIcon_jiju_Icon_128',
#     'talent_description': '积聚魔导师+1 聚能祝福层数上限每有 1 层聚能祝福， 额外 +3% 法术伤害',
#     'talent_type': 'main'},
#    {'talent_name': '内能',
#     'talent_id': 'UI_CoreTalentIcon_neineng_Icon_128',
#     'talent_description': '内能魔导师护盾返还量翻倍',
#     'talent_type': 'main'},
#    {'talent_name': '甲壳',
#     'talent_id': 'UI_CoreTalentIcon_jiaqiao_Icon_128',
#     'talent_description': '甲壳魔导师额外 +30% 最大护盾最大生命固定为 100',
#     'talent_type': 'main'},
#    {'talent_name': '稳扎稳打',
#     'talent_id': 'UI_CoreTalentIcon_wenzhawenda_Icon_128',
#     'talent_description': '稳扎稳打魔导师对施法速度的加成与额外加成的 100% 同样作用于法术迸发充能速度非法术迸发释放的技能额外 -50% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '光辉结界',
#     'talent_id': 'UI_CoreTalentIcon_guanghuijiejie_Icon_128',
#     'talent_description': '光辉结界魔导师最近开启的护盾充能无法被伤害打断+50% 护盾充能速度',
#     'talent_type': 'main'},
#    {'talent_name': '心灵利刃',
#     'talent_id': 'UI_CoreTalentIcon_xinlingliren_Icon_128',
#     'talent_description': '心灵利刃魔导师未携带法杖、锡杖时，额外 +30% 法术伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Arcanist': {'talent_name': '秘术师',
#   'talent_main_attribute': [],
#   'talent_tags': ['冰冷', '魔力'],
#   'main_talent_lst': [{'talent_name': '冻伤',
#     'talent_id': 'UI_CoreTalentIcon_dongshang_Icon_128',
#     'talent_description': '冻伤秘术师对冰封的敌人额外 +60% 伤害对敌人首次造成冰冷伤害时，施加冰结和 100 冰结值',
#     'talent_type': 'main'},
#    {'talent_name': '魔能',
#     'talent_id': 'UI_CoreTalentIcon_moneng_Icon_128',
#     'talent_description': '魔能秘术师20% 的伤害优先抵扣魔力额外 +12% 最大魔力',
#     'talent_type': 'main'},
#    {'talent_name': '满载',
#     'talent_id': 'UI_CoreTalentIcon_manzai_Icon_128',
#     'talent_description': '满载秘术师释放技能时，消耗 15% 当前魔力，此效果对迸发不会生效魔力达到上限时，下一次技能额外 +20% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '刺骨极寒',
#     'talent_id': 'UI_CoreTalentIcon_bingdian_Icon_128',
#     'talent_description': '刺骨极寒秘术师你施加的冰封获得额外效果：额外 +20% 受到的冰冷伤害',
#     'talent_type': 'main'},
#    {'talent_name': '冰冻之莲',
#     'talent_id': 'UI_CoreTalentIcon_bingdongzhilian_Icon_128',
#     'talent_description': '冰冻之莲秘术师额外 +25% 冰冷伤害当前魔力低于 15% 时，额外 -100% 技能消耗',
#     'talent_type': 'main'},
#    {'talent_name': '聚气凝神',
#     'talent_id': 'UI_CoreTalentIcon_juqiningshen_Icon_128',
#     'talent_description': '聚气凝神秘术师聚能祝福的基础效果转换为：攻击和法术附加等同于 0.5% 最大魔力的冰冷伤害聚能祝福层数上限最大为 8',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Elementalist': {'talent_name': '元素师',
#   'talent_main_attribute': [],
#   'talent_tags': ['引导', '元素'],
#   'main_talent_lst': [{'talent_name': '专注',
#     'talent_id': 'UI_CoreTalentIcon_zhuanzhu_Icon_128',
#     'talent_description': '专注元素师+2 引导层数上限每有 +1 额外引导层数上限，额外 +5% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '适应',
#     'talent_id': 'UI_CoreTalentIcon_shiying_Icon_128',
#     'talent_description': '适应元素师25% 受到的物理伤害转化为随机元素伤害+4% 元素抗性上限',
#     'talent_type': 'main'},
#    {'talent_name': '透明',
#     'talent_id': 'UI_CoreTalentIcon_touming_Icon_128',
#     'talent_description': '透明元素师如果最近造成了火焰伤害，额外 +20% 闪电伤害如果最近造成了闪电伤害，额外 +20% 冰冷伤害如果最近造成了冰冷伤害，额外 +20% 火焰伤害',
#     'talent_type': 'main'},
#    {'talent_name': '快速仪式',
#     'talent_id': 'UI_CoreTalentIcon_kuaisuyishi_Icon_128',
#     'talent_description': '快速仪式元素师+1 引导层数下限额外 +20% 引导技能伤害',
#     'talent_type': 'main'},
#    {'talent_name': '奇幻莫测',
#     'talent_id': 'UI_CoreTalentIcon_qihuanmoce_Icon_128',
#     'talent_description': '奇幻莫测元素师+50% 几率造成元素异常状态对元素异常状态下的敌人，额外 +25% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '入木三分',
#     'talent_id': 'UI_CoreTalentIcon_rumusanfen_Icon_128',
#     'talent_description': '入木三分元素师每有 1 层聚能祝福， 额外 +4% 元素伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Shadowdancer': {'talent_name': '影舞者',
#   'talent_main_attribute': [],
#   'talent_tags': ['物理', '触发'],
#   'main_talent_lst': [{'talent_name': '钝器',
#     'talent_id': 'UI_CoreTalentIcon_dunqi_Icon_128',
#     'talent_description': '钝器影舞者额外 +24% 物理伤害敌人 +20% 受伤缓冲',
#     'talent_type': 'main'},
#    {'talent_name': '断续',
#     'talent_id': 'UI_CoreTalentIcon_duanxu_Icon_128',
#     'talent_description': '断续影舞者攻击暴击时， +350 法术暴击值，持续 4 秒',
#     'talent_type': 'main'},
#    {'talent_name': '野心',
#     'talent_id': 'UI_CoreTalentIcon_yexin_Icon_128',
#     'talent_description': '野心影舞者击中劲敌时，获得 10 点战意值周围有敌人时，获得战意',
#     'talent_type': 'main'},
#    {'talent_name': '伤口撕裂',
#     'talent_id': 'UI_CoreTalentIcon_shangkousilie_Icon_128',
#     'talent_description': '伤口撕裂影舞者对创伤状态下的敌人，再次造成创伤时，+50% 创伤持续时间对创伤状态下的敌人， +125% 暴击伤害对创伤状态下的敌人，召唤物 +125% 暴击伤害',
#     'talent_type': 'main'},
#    {'talent_name': '一触即发',
#     'talent_id': 'UI_CoreTalentIcon_lingguangzhaxian_Icon_128',
#     'talent_description': '一触即发影舞者每有 7 点战意值，触发技能时，该技能额外 +2% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '内外兼修',
#     'talent_id': 'UI_CoreTalentIcon_neiwaijianxiu_Icon_128',
#     'talent_description': '内外兼修影舞者最近每释放一次攻击技能，额外 +9% 法术伤害，最多叠加 3 层如果最近法术击中，额外 +25% 攻击伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Ronin': {'talent_name': '神行武士',
#   'talent_main_attribute': [],
#   'talent_tags': ['近战', '格挡'],
#   'main_talent_lst': [{'talent_name': '挥洒',
#     'talent_id': 'UI_CoreTalentIcon_huisa_Icon_128',
#     'talent_description': '挥洒神行武士近战技能有 30% 几率 +30% 技能范围额外 +18% 近战伤害',
#     'talent_type': 'main'},
#    {'talent_name': '守势',
#     'talent_id': 'UI_CoreTalentIcon_shoushi_Icon_128',
#     'talent_description': '守势神行武士+25% 格挡比例额外格挡 100 点伤害',
#     'talent_type': 'main'},
#    {'talent_name': '聚权',
#     'talent_id': 'UI_CoreTalentIcon_juquan_Icon_128',
#     'talent_description': '聚权神行武士击中时，额外获得当前战意值 25% 的战意值，冷却时间 0.3 秒受击时消耗一半当前的战意值，每消耗 1 点，额外 -0.8% 该次伤害',
#     'talent_type': 'main'},
#    {'talent_name': '权衡轻重',
#     'talent_id': 'UI_CoreTalentIcon_quanhengqingzhong_Icon_128',
#     'talent_description': '权衡轻重神行武士当敏捷不小于力量时，额外 +25% 攻击速度当力量不小于敏捷时，额外 +25% 攻击伤害',
#     'talent_type': 'main'},
#    {'talent_name': '全面防御',
#     'talent_id': 'UI_CoreTalentIcon_quanmianfangyu_Icon_128',
#     'talent_description': '全面防御神行武士额外 +100% 从盾牌获得的防御值每 2% 格挡比例，额外 -3% 受到的持续伤害',
#     'talent_type': 'main'},
#    {'talent_name': '落叶飞花',
#     'talent_id': 'UI_CoreTalentIcon_juediyiji_Icon_128',
#     'talent_description': '落叶飞花神行武士额外 -20% 武器伤害额外 +40% 攻击伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Ranger': {'talent_name': '游侠',
#   'talent_main_attribute': [],
#   'talent_tags': ['暴击', '距离'],
#   'main_talent_lst': [{'talent_name': '侥幸',
#     'talent_id': 'UI_CoreTalentIcon_jiaoxing_Icon_128',
#     'talent_description': '侥幸游侠拥有至少 50 点战意值时，暴击幸运',
#     'talent_type': 'main'},
#    {'talent_name': '引力',
#     'talent_id': 'UI_CoreTalentIcon_yinli_Icon_128',
#     'talent_description': '引力游侠额外 +20% 近战伤害近战技能具有反向击退',
#     'talent_type': 'main'},
#    {'talent_name': '流矢',
#     'talent_id': 'UI_CoreTalentIcon_liushi_Icon_128',
#     'talent_description': '流矢游侠额外 +20% 投射物伤害+50% 击退距离',
#     'talent_type': 'main'},
#    {'talent_name': '再接再厉',
#     'talent_id': 'UI_CoreTalentIcon_zaijiezaili_Icon_128',
#     'talent_description': '再接再厉游侠每 4 点战意值，额外 +1% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '近在眉睫',
#     'talent_id': 'UI_CoreTalentIcon_jinzaimeijie_Icon_128',
#     'talent_description': '近在眉睫游侠每隔 0.25 秒，使 10 米内敌人受到的来自你的伤害额外 +6%，该效果最多叠加 5 层',
#     'talent_type': 'main'},
#    {'talent_name': '强弓劲弩',
#     'talent_id': 'UI_CoreTalentIcon_qianggongjinnu_Icon_128',
#     'talent_description': '强弓劲弩游侠投射物伤害随飞行距离递增：对远处的敌人至多额外 +35% 伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Shadowmaster': {'talent_name': '驭影者',
#   'talent_main_attribute': [],
#   'talent_tags': ['腐蚀', '封印'],
#   'main_talent_lst': [{'talent_name': '污垢',
#     'talent_id': 'UI_CoreTalentIcon_xuewu_Icon_128',
#     'talent_description': '污垢驭影者额外 +15% 腐蚀伤害对生命造成额外 15% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '结界',
#     'talent_id': 'UI_CoreTalentIcon_jiejie_Icon_128',
#     'talent_description': '结界驭影者附加 25% 已封印魔力的护盾',
#     'talent_type': 'main'},
#    {'talent_name': '隐刺',
#     'talent_id': 'UI_CoreTalentIcon_yinci_Icon_128',
#     'talent_description': '隐刺驭影者具有迷踪时，额外 -20% 受到的伤害失去迷踪后的 3 秒内，额外 +25% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '病入膏肓',
#     'talent_id': 'UI_CoreTalentIcon_bingrugaohuang_Icon_128',
#     'talent_description': '病入膏肓驭影者造成伤害时，敌人每有一层凋零，额外 +3% 腐蚀伤害，最多额外 +30%',
#     'talent_type': 'main'},
#    {'talent_name': '扭曲信仰',
#     'talent_id': 'UI_CoreTalentIcon_niuquxinyang_Icon_128',
#     'talent_description': '扭曲信仰驭影者+4 腐蚀技能等级-2 元素技能等级',
#     'talent_type': 'main'},
#    {'talent_name': '生命转换',
#     'talent_id': 'UI_CoreTalentIcon_xuerouxianji_Icon_128',
#     'talent_description': '生命转换驭影者附加 20% 已封印生命的魔力',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Psychic': {'talent_name': '异能者',
#   'talent_main_attribute': [],
#   'talent_tags': ['持续', '负面效果'],
#   'main_talent_lst': [{'talent_name': '加剧',
#     'talent_id': 'UI_CoreTalentIcon_jiaju_Icon_128',
#     'talent_description': '加剧异能者+10 每秒施加加剧值额外 +30% 加剧效果',
#     'talent_type': 'main'},
#    {'talent_name': '圣洁',
#     'talent_id': 'UI_CoreTalentIcon_shengjie_Icon_128',
#     'talent_description': '圣洁异能者免疫诅咒额外 -20% 来自被诅咒的敌人伤害',
#     'talent_type': 'main'},
#    {'talent_name': '迷乱',
#     'talent_id': 'UI_CoreTalentIcon_miluan_Icon_128',
#     'talent_description': '迷乱异能者迷踪获得额外效果：+40% 控制类状态效果；额外 +20% 异常伤害',
#     'talent_type': 'main'},
#    {'talent_name': '事半功倍',
#     'talent_id': 'UI_CoreTalentIcon_shibangongbei_Icon_128',
#     'talent_description': '事半功倍异能者额外 +50% 持续伤害额外 -30% 持续伤害持续时间',
#     'talent_type': 'main'},
#    {'talent_name': '污言秽语',
#     'talent_id': 'UI_CoreTalentIcon_wuyanhuiyu_Icon_128',
#     'talent_description': '污言秽语异能者你可以施加 1 个额外诅咒+10% 诅咒效果',
#     'talent_type': 'main'},
#    {'talent_name': '净化切割',
#     'talent_id': 'UI_CoreTalentIcon_jinghuaqiege_Icon_128',
#     'talent_description': '净化切割异能者收割时，额外结算 25% 的剩余总伤害，然后移除目标具有的所有持续伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Warlock': {'talent_name': '暗影术士',
#   'talent_main_attribute': [],
#   'talent_tags': ['技能', '异常'],
#   'main_talent_lst': [{'talent_name': '前奏',
#     'talent_id': 'UI_CoreTalentIcon_qianzou_Icon_128',
#     'talent_description': '前奏暗影术士使用非核心技能会使下一次核心技能额外 +25% 伤害，该效果不可叠加',
#     'talent_type': 'main'},
#    {'talent_name': '卑劣',
#     'talent_id': 'UI_CoreTalentIcon_beilie_Icon_128',
#     'talent_description': '卑劣暗影术士暴击造成的异常状态持续时间翻倍每 +3% 暴击伤害，额外 +1% 异常伤害',
#     'talent_type': 'main'},
#    {'talent_name': '冷眼',
#     'talent_id': 'UI_CoreTalentIcon_lengxue_Icon_128',
#     'talent_description': '冷眼暗影术士+2 全部技能等级',
#     'talent_type': 'main'},
#    {'talent_name': '独辟蹊径',
#     'talent_id': 'UI_CoreTalentIcon_dupixijing_Icon_128',
#     'talent_description': '独辟蹊径暗影术士+4 辅助技能等级辅助技能魔力倍率固定为 95%',
#     'talent_type': 'main'},
#    {'talent_name': '肮脏技巧',
#     'talent_id': 'UI_CoreTalentIcon_angzangjiqiao_Icon_128',
#     'talent_description': '肮脏技巧暗影术士击中时，必定造成所有异常状态造成伤害时，敌人每有一种异常状态，额外 +6% 伤害（叠乘）',
#     'talent_type': 'main'},
#    {'talent_name': '暗箭难防',
#     'talent_id': 'UI_CoreTalentIcon_anyingtuxi_Icon_128',
#     'talent_description': '暗箭难防暗影术士具有迷踪时，释放核心技能后会失去迷踪，并使该次技能额外 +35% 伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Machinist': {'talent_name': '机械师',
#   'talent_main_attribute': [],
#   'talent_tags': ['智械', '哨卫'],
#   'main_talent_lst': [{'talent_name': '领主',
#     'talent_id': 'UI_CoreTalentIcon_lingzhu_Icon_128',
#     'talent_description': '领主机械师+1 智械召唤物数量上限额外 +10% 召唤物伤害',
#     'talent_type': 'main'},
#    {'talent_name': '预热',
#     'talent_id': 'UI_CoreTalentIcon_yure_Icon_128',
#     'talent_description': '预热机械师如果最近释放过哨卫技能，额外 +30% 哨卫伤害额外 -30% 哨卫启动时间',
#     'talent_type': 'main'},
#    {'talent_name': '碎壳',
#     'talent_id': 'UI_CoreTalentIcon_suike_Icon_128',
#     'talent_description': '碎壳机械师屏障吸收比例固定为 99%屏障只能承受一次击中伤害+150% 屏障吸收量',
#     'talent_type': 'main'},
#    {'talent_name': '侵略如火',
#     'talent_id': 'UI_CoreTalentIcon_qinlueruhuo_Icon_128',
#     'talent_description': '侵略如火机械师10 米内有首领时，每隔 2 秒，获得 20 点统御值',
#     'talent_type': 'main'},
#    {'talent_name': '同频共振',
#     'talent_id': 'UI_CoreTalentIcon_tongpingongzhen_Icon_128',
#     'talent_description': '同频共振机械师对于攻击速度的加成和额外加成的 100% 同样作用于攻击哨卫的释放频率对于施法速度的加成和额外加成的 100% 同样作用于法术哨卫的释放频率',
#     'talent_type': 'main'},
#    {'talent_name': '动能转化',
#     'talent_id': 'UI_CoreTalentIcon_dongnengzhuanhua_Icon_128',
#     'talent_description': '动能转化机械师移动时，受到伤害额外 -20%每移动 5 米， 100% 几率获得屏障',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Steel_Vanguard': {'talent_name': '钢铁先锋',
#   'talent_main_attribute': [],
#   'talent_tags': ['增益效果', '抗性'],
#   'main_talent_lst': [{'talent_name': '映射',
#     'talent_id': 'UI_CoreTalentIcon_yingshe_Icon_128',
#     'talent_description': '映射钢铁先锋每受到一种光环影响，额外 +5% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '抵抗',
#     'talent_id': 'UI_CoreTalentIcon_dikang_Icon_128',
#     'talent_description': '抵抗钢铁先锋+3% 元素抗性上限+15% 元素抗性',
#     'talent_type': 'main'},
#    {'talent_name': '帷幕',
#     'talent_id': 'UI_CoreTalentIcon_weimu_Icon_128',
#     'talent_description': '帷幕钢铁先锋+35% 屏障吸收量获得屏障时，刷新屏障',
#     'talent_type': 'main'},
#    {'talent_name': '博闻强识',
#     'talent_id': 'UI_CoreTalentIcon_bowenqiangshi_Icon_128',
#     'talent_description': '博闻强识钢铁先锋+10 激发技能等级+10 防护技能等级',
#     'talent_type': 'main'},
#    {'talent_name': '百恶不侵',
#     'talent_id': 'UI_CoreTalentIcon_baidubuqin_Icon_128',
#     'talent_description': '百恶不侵钢铁先锋+5% 腐蚀抗性上限25% 受到的物理和元素伤害转化为腐蚀伤害',
#     'talent_type': 'main'},
#    {'talent_name': '灵丹妙药',
#     'talent_id': 'UI_CoreTalentIcon_lingdanmiaoyao_Icon_128',
#     'talent_description': '灵丹妙药钢铁先锋回复技能 +100% 回复效果回复技能的回复效果不会移除',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'Alchemist': {'talent_name': '炼金术士',
#   'talent_main_attribute': [],
#   'talent_tags': ['魔灵', '回复'],
#   'main_talent_lst': [{'talent_name': '源泉',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '源泉炼金术士魔灵技能 +50% 魔力封印补偿额外 +30% 魔灵之源效果魔灵额外 +30% 激发技能效果',
#     'talent_type': 'main'},
#    {'talent_name': '应急',
#     'talent_id': 'UI_CoreTalentIcon_yingji_Icon_128',
#     'talent_description': '应急炼金术士每损失 2% 生命，1.5% 生命自然回复速度每损失 2% 魔力，1.5% 魔力自然回复速度',
#     'talent_type': 'main'},
#    {'talent_name': '赋能',
#     'talent_id': 'UI_CoreTalentIcon_funeng_Icon_128',
#     'talent_description': '赋能炼金术士附加 25% 最大生命至屏障吸收量附加 25% 最大护盾至屏障吸收量',
#     'talent_type': 'main'},
#    {'talent_name': '冲锋号角',
#     'talent_id': 'UI_CoreTalentIcon_chongfenghaojiao_Icon_128',
#     'talent_description': '冲锋号角炼金术士额外 -10% 召唤物攻击和施法速度魔灵 +50% 强化技能使用几率',
#     'talent_type': 'main'},
#    {'talent_name': '活性超流',
#     'talent_id': 'UI_CoreTalentIcon_huoxingchaoliu_Icon_128',
#     'talent_description': '活性超流炼金术士溢出的魔力自然回复作用于生命每秒自然回复 4% 魔力',
#     'talent_type': 'main'},
#    {'talent_name': '深渊爪牙',
#     'talent_id': 'UI_CoreTalentIcon_shenyuanzhaoya_Icon_128',
#     'talent_description': '深渊爪牙炼金术士魔灵每有 20 点生长值，额外 +1% 伤害魔灵每有 40 点生长值，额外 +1% 冷却回复速度',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []},
#  'New_God': {'talent_name': '新神',
#   'talent_main_attribute': [],
#   'talent_tags': [],
#   'main_talent_lst': [{'talent_name': '万界如常',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '万界如常新神每 3 秒获得 1 点秩序值',
#     'talent_type': 'main'},
#    {'talent_name': '万界祸乱',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '万界祸乱新神击败时，失去 1 点秩序值首次遭遇首领敌人时，失去一半当前的秩序值',
#     'talent_type': 'main'},
#    {'talent_name': '万界入寂',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '万界入寂新神固定拥有 50 点秩序值+25% 秩序值效果+25% 混乱值效果',
#     'talent_type': 'main'},
#    {'talent_name': '龙息绝',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '龙息绝新神吞噬坚韧祝福后，接下来若干次核心攻击技能 +100% 技能范围且额外 +60% 伤害，每吞噬 1 层坚韧祝福，该次数 +1新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '繁星坠',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '繁星坠新神吞噬灵动祝福后，接下来若干次核心攻击技能额外 +120% 攻击速度，接下来若干次核心法术技能额外 +120% 施法速度；每吞噬 1 层灵动祝福，该次数 +1；该效果对引导和哨卫技能无效新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '长梦醒',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '长梦醒新神吞噬聚能祝福后，接下来若干次核心法术技能 +100% 几率造成双倍伤害，每吞噬 1 层聚能祝福，该次数 +1新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '征伐终',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '征伐终新神吞噬战意后，每吞噬 1 点战意值，+4% 暴击伤害，并在接下来的 4 秒内衰减到 0新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '诳语破',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '诳语破新神吞噬迷踪后，每吞噬 1 点迷踪值，+1% 控制类状态效果，并在接下来的 4 秒内衰减到 0新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '高城覆',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '高城覆新神吞噬屏障后，每吞噬 1 点屏障值，在接下来的 4 秒内回复 1.5 点生命与护盾新神正在吞噬六神的恩泽',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [],
#   'legend_mid_talent_lst': []}}

# %% [markdown]
# ### 1.3 解析中小型天赋

# %%
talent_type_map = {'小型天赋':'mini_talent_lst',
                   '中型天赋':'mid_talent_lst',
                   '传奇中型天赋':'legend_mid_talent_lst'
                  }

# %%
# 找到id为MainTalentNode的div标签
talent_node = soup.find(name='div', attrs={"id":talent_key_map["Talent"]})

for col_node in talent_node.find_all(name='div',attrs={"class":"col"}):
    talent_node = {'talent_id':'',
                   'talent_name':'',
                   'talent_type':'',
                  'talent_description':''}
    tid = col_node.find('img').attrs['src'].split('\\')[1].removesuffix('.webp')

    href = col_node.find('a').attrs['href']

    talent_type = col_node.find_all('span')[0].text

    desc = ''.join([i.text for i in col_node.find('div',class_="flex-grow-1 mx-2 my-1")][1:])

    insert_key = talent_type_map[talent_type]
    
    talent_node['talent_id'] = tid
    talent_node['talent_description'] = desc
    talent_node['talent_type'] = insert_key.removesuffix('_talent_lst')

    talent_nodes[href][insert_key].append(talent_node)

# %%
talent_nodes
# Out:
# {'God_of_Might': {'talent_name': '巨力之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['攻击', '火焰'],
#   'main_talent_lst': [{'talent_name': '淘汰',
#     'talent_id': 'UI_CoreTalentIcon_taotai_Icon_128',
#     'talent_description': '淘汰巨力之神攻击击中时，淘汰生命值低于 18% 的敌人',
#     'talent_type': 'main'},
#    {'talent_name': '燃尽',
#     'talent_id': 'UI_CoreTalentIcon_ranjin_Icon_128',
#     'talent_description': '燃尽巨力之神额外 +24% 火焰伤害重创敌人时，使敌人 +20% 火焰抗性，持续 1 秒',
#     'talent_type': 'main'},
#    {'talent_name': '坚韧',
#     'talent_id': 'UI_CoreTalentIcon_jianren_Icon_128',
#     'talent_description': '坚韧巨力之神击中敌人时，+100% 几率获得 1 层坚韧祝福+1 坚韧祝福层数上限',
#     'talent_type': 'main'},
#    {'talent_name': '势大力沉',
#     'talent_id': 'UI_CoreTalentIcon_shidalichen_Icon_128',
#     'talent_description': '势大力沉巨力之神-10% 攻击速度额外 +30% 攻击伤害额外 +30% 攻击造成的异常伤害',
#     'talent_type': 'main'},
#    {'talent_name': '火上浇油',
#     'talent_id': 'UI_CoreTalentIcon_huoshangjiaoyou_Icon_128',
#     'talent_description': '火上浇油巨力之神伤害无视敌人火焰抗性',
#     'talent_type': 'main'},
#    {'talent_name': '燎原烈火',
#     'talent_id': 'UI_CoreTalentIcon_liaoyuanliehuo_Icon_128',
#     'talent_description': '燎原烈火巨力之神额外 +20% 火焰持续伤害造成火焰伤害时，施加 10 加剧值，冷却时间 0.1 秒',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击速度'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 施法速度'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+10% 攻击暴击值+3% 暴击伤害'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+5% 护甲值+2% 最大生命'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8% 点燃伤害+6% 点燃几率'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 攻击伤害+2% 移动速度'},
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+10% 坚韧祝福持续时间拥有坚韧祝福时， 1.5% 元素抗性'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 火焰伤害'},
#    {'talent_id': 'Crossbow02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8 力量'},
#    {'talent_id': 'Dagger01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+2% 最大生命1.5% 生命返还'}],
#   'mid_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击速度-4 攻击技能消耗'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 施法速度+5% 火焰技能范围'},
#    {'talent_id': 'Crit03_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+9% 投射物速度+25% 远程攻击暴击值'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+10% 技能范围+10% 近战攻击暴击伤害'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+10% 护甲值+4% 最大生命'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+16% 点燃伤害+12% 点燃几率'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 攻击伤害+4% 移动速度'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 火焰抗性50% 物理伤害转化为火焰伤害'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+4% 最大生命+3% 生命返还'}],
#   'legend_mid_talent_lst': [{'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每有 1 层坚韧祝福， +3% 生命自然回复速度每有 1 层坚韧祝福，每秒自然回复 25 生命'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每 6 点力量， +1% 火焰伤害'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 攻击技能等级'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每隔 1 秒，额外 +12% 下一次核心技能造成的火焰伤害'}]},
#  'Goddess_of_Hunting': {'talent_name': '狩猎之神',
#   'talent_main_attribute': ['敏捷'],
#   'talent_tags': ['速度', '闪电'],
#   'main_talent_lst': [{'talent_name': '敏锐',
#     'talent_id': 'UI_CoreTalentIcon_minrui_Icon_128',
#     'talent_description': '敏锐狩猎之神击中敌人时，+100% 概率获得 1 层灵动祝福+1 灵动祝福层数上限',
#     'talent_type': 'main'},
#    {'talent_name': '感电',
#     'talent_id': 'UI_CoreTalentIcon_mabi_Icon_128',
#     'talent_description': '感电狩猎之神如果在 0.2 秒内造成过闪电伤害，额外 +20% 闪电伤害',
#     'talent_type': 'main'},
#    {'talent_name': '闪烁',
#     'talent_id': 'UI_CoreTalentIcon_shanshuo_Icon_128',
#     'talent_description': '闪烁狩猎之神额外 +50% 位移技能冷却回复速度额外 +25% 位移技能攻击与施法速度',
#     'talent_type': 'main'},
#    {'talent_name': '行色匆匆',
#     'talent_id': 'UI_CoreTalentIcon_xingsecongcong_Icon_128',
#     'talent_description': '行色匆匆狩猎之神如果最近移动了超过 5 米，额外 +30% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '世事无常',
#     'talent_id': 'UI_CoreTalentIcon_shishiwuchang_Icon_128',
#     'talent_description': '世事无常狩猎之神额外 -40% 最小伤害额外 +40% 最大伤害',
#     'talent_type': 'main'},
#    {'talent_name': '灵光一现',
#     'talent_id': 'UI_CoreTalentIcon_lingguangyixian_Icon_128',
#     'talent_description': '灵光一现狩猎之神对法术伤害，闪避值不再默认额外降低额外 +20% 闪避值',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击与施法速度'},
#    {'talent_id': 'Dagger02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命+3% 最大护盾'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+2% 移动速度'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 技能范围+5% 投射物速度'},
#    {'talent_id': 'Evasion_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 闪避值'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8 敏捷'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8% 闪电伤害+6% 麻痹几率'},
#    {'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击速度'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 施法速度'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '1.5% 生命返还1.5% 护盾返还'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 闪电伤害'}],
#   'mid_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击与施法速度-4 技能消耗'},
#    {'talent_id': 'DmgLightning_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+6% 最大护盾'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+3% 移动速度+15% 位移技能冷却回复速度'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+14% 技能范围+10% 投射物速度'},
#    {'talent_id': 'Evasion_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+10% 闪避值闪避时，+15% 概率获得 1 层灵动祝福，间隔 1 秒'},
#    {'talent_id': 'Electrocute_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+4% 敏捷'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+12% 麻痹几率50% 物理伤害转化为闪电伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+40% 攻击暴击值'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+3% 生命返还+3% 护盾返还'}],
#   'legend_mid_talent_lst': [{'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+25% 麻痹效果'},
#    {'talent_id': 'Crossbow01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '如果最近有暴击，额外 +10% 攻击速度'},
#    {'talent_id': 'Bleed_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '最近每使用 1 次法术技能，+4% 暴击伤害，最多叠加 16 层'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '额外 +15% 最大伤害'}]},
#  'Goddess_of_Knowledge': {'talent_name': '知识之神',
#   'talent_main_attribute': ['智慧'],
#   'talent_tags': ['法术', '冰冷'],
#   'main_talent_lst': [{'talent_name': '灯塔',
#     'talent_id': 'UI_CoreTalentIcon_dengta_Icon_128',
#     'talent_description': '灯塔知识之神法术迸发上限 +2',
#     'talent_type': 'main'},
#    {'talent_name': '苦寒',
#     'talent_id': 'UI_CoreTalentIcon_kuhan_Icon_128',
#     'talent_description': '苦寒知识之神击中时，+100% 几率获得 1 层聚能祝福+1 聚能祝福层数上限',
#     'talent_type': 'main'},
#    {'talent_name': '凛冬',
#     'talent_id': 'UI_CoreTalentIcon_yongdongzhizhou_Icon_128',
#     'talent_description': '凛冬知识之神敌人每有 2 点冰结值，对其额外 +1% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '别具慧眼',
#     'talent_id': 'UI_CoreTalentIcon_biejuhuiyan_Icon_128',
#     'talent_description': '别具慧眼知识之神额外 +30% 法术伤害额外 +25% 技能消耗',
#     'talent_type': 'main'},
#    {'talent_name': '炙手可热',
#     'talent_id': 'UI_CoreTalentIcon_zhishoukere_Icon_128',
#     'talent_description': '炙手可热知识之神免疫冰结额外 +20% 冰冷和火焰伤害',
#     'talent_type': 'main'},
#    {'talent_name': '养精蓄锐',
#     'talent_id': 'UI_CoreTalentIcon_yangjingxurui_Icon_128',
#     'talent_description': '养精蓄锐知识之神每消耗 6% 魔力，获得 1 层聚能祝福，间隔 0.3 秒额外 -50% 聚能祝福持续时间聚能祝福达到上限时，额外 +25% 施法速度',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击与施法速度2.5% 移动速度'},
#    {'talent_id': 'Dual02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+6% 最大魔力'},
#    {'talent_id': 'Crit04_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+15% 暴击值'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 技能范围4.5% 投射物速度'},
#    {'talent_id': 'Aura_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命+3% 最大护盾'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+4% 法术迸发充能速度'},
#    {'talent_id': 'DmgLightning_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害'},
#    {'talent_id': 'Defence02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '1.5% 护盾返还'},
#    {'talent_id': 'Dual03_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8% 冰冷伤害+6% 冰结几率'},
#    {'talent_id': 'Dual01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8 智慧'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 法术伤害'},
#    {'talent_id': 'Crit01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+10% 聚能祝福持续时间拥有聚能祝福时， +10% 伤害'}],
#   'mid_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击与施法速度-4 技能消耗+5% 移动速度'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+12% 最大魔力击中时，回复 6 魔力'},
#    {'talent_id': 'Crit04_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+20% 暴击值+5% 暴击伤害'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+14% 技能范围+9% 投射物速度'},
#    {'talent_id': 'Aura_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+6% 最大护盾'},
#    {'talent_id': 'Aura_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+8% 法术迸发充能速度'},
#    {'talent_id': 'DmgChaos_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+3% 护盾返还'},
#    {'talent_id': 'Dual03_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+16% 冰冷伤害+12% 冰结几率50% 物理伤害转化为冰冷伤害'},
#    {'talent_id': 'EsReg_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+4% 智慧'}],
#   'legend_mid_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 法术技能等级'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 聚能祝福层数上限'},
#    {'talent_id': 'Ailment_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '造成冰封时，+100% 几率获得 1 层聚能祝福对冰结的敌人，额外 +8% 伤害'}]},
#  'God_of_War': {'talent_name': '征战之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['几率', '物理'],
#   'main_talent_lst': [{'talent_name': '凝聚',
#     'talent_id': 'UI_CoreTalentIcon_ningju_Icon_128',
#     'talent_description': '凝聚征战之神每隔 1 秒，下一次核心技能额外 +50% 暴击值',
#     'talent_type': 'main'},
#    {'talent_name': '残暴',
#     'talent_id': 'UI_CoreTalentIcon_canbao_Icon_128',
#     'talent_description': '残暴征战之神额外 +25% 物理伤害每 5 等级，额外 -1% 元素伤害',
#     'talent_type': 'main'},
#    {'talent_name': '坚强',
#     'talent_id': 'UI_CoreTalentIcon_jianqiang_Icon_128',
#     'talent_description': '坚强征战之神受到巨额伤害后，保留1点生命，并且免疫持续伤害1秒，该效果具有 8 秒冷却时间',
#     'talent_type': 'main'},
#    {'talent_name': '自主升级',
#     'talent_id': 'UI_CoreTalentIcon_zizhushengji_Icon_128',
#     'talent_description': '自主升级征战之神+20% 攻击与法术格挡率最近每格挡 1 次，+5% 攻击与法术格挡率，至多叠加 5 层',
#     'talent_type': 'main'},
#    {'talent_name': '迎头痛击',
#     'talent_id': 'UI_CoreTalentIcon_yingtoutongji_Icon_128',
#     'talent_description': '迎头痛击征战之神额外 +100% 暴击造成的创伤伤害',
#     'talent_type': 'main'},
#    {'talent_name': '无边战意',
#     'talent_id': 'UI_CoreTalentIcon_wubianzhanyi_Icon_128',
#     'talent_description': '无边战意征战之神拥有战意+12% 战意效果',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害'},
#    {'talent_id': 'Crit04_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+15% 暴击值'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 技能范围+5% 投射物速度+2% 移动速度'},
#    {'talent_id': 'Evasion_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '2.5% 防御值1.5% 几率避免伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '2.5% 攻击格挡率2.5% 法术格挡率'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命+3% 防御值'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 物理伤害'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击与施法速度'},
#    {'talent_id': 'Dual01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '1.5% 生命返还1.5% 护盾返还'},
#    {'talent_id': 'Curse_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8% 创伤伤害+2% 创伤持续时间'}],
#   'mid_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害'},
#    {'talent_id': 'Crit02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+25% 暴击值暴击时，回复 6 魔力'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+14% 技能范围+10% 投射物速度+3% 移动速度'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 防御值+3% 几率避免伤害'},
#    {'talent_id': 'Block_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 攻击格挡率+5% 法术格挡率'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+6% 防御值'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害'},
#    {'talent_id': 'Aura_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 物理伤害'},
#    {'talent_id': 'Crit01_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 攻击速度+10% 暴击伤害'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 施法速度+10% 暴击伤害'}],
#   'legend_mid_talent_lst': [{'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '格挡时，10% 几率回复 15% 生命、护盾和魔力'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 物理技能等级'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+24% 连续攻击几率'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '使用核心法术技能时，+12% 几率额外触发一次'},
#    {'talent_id': 'Defence03_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+8% 生命返还受到重创时，回复 20% 已损生命'},
#    {'talent_id': 'Defence03_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+8% 护盾返还受到重创时，回复 20% 已损护盾'},
#    {'talent_id': 'Crit01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '额外 +12% 暴击造成的创伤伤害'}]},
#  'Goddess_of_Deception': {'talent_name': '欺诈之神',
#   'talent_main_attribute': ['敏捷'],
#   'talent_tags': ['持续', '腐蚀'],
#   'main_talent_lst': [{'talent_name': '瘟疫',
#     'talent_id': 'UI_CoreTalentIcon_wenyi_Icon_128',
#     'talent_description': '瘟疫欺诈之神持续伤害有 50% 几率扩散至周围目标+30% 持续伤害持续时间',
#     'talent_type': 'main'},
#    {'talent_name': '混入',
#     'talent_id': 'UI_CoreTalentIcon_hunru_Icon_128',
#     'talent_description': '混入欺诈之神99% 元素伤害转化为腐蚀伤害对敌人造成伤害时，+99% 几率使目标瘫痪',
#     'talent_type': 'main'},
#    {'talent_name': '疾徐',
#     'talent_id': 'UI_CoreTalentIcon_jixu_Icon_128',
#     'talent_description': '疾徐欺诈之神施加持续伤害后 2 秒内，额外 +25% 持续伤害，该效果不可叠加',
#     'talent_type': 'main'},
#    {'talent_name': '潜移默化',
#     'talent_id': 'UI_CoreTalentIcon_qianyimohua_Icon_128',
#     'talent_description': '潜移默化欺诈之神迷踪获得额外效果：额外 +25% 持续伤害',
#     'talent_type': 'main'},
#    {'talent_name': '禁忌力量',
#     'talent_id': 'UI_CoreTalentIcon_jinjililiang_Icon_128',
#     'talent_description': '禁忌力量欺诈之神额外 +40% 腐蚀伤害-15% 元素抗性',
#     'talent_type': 'main'},
#    {'talent_name': '饮鸩止渴',
#     'talent_id': 'UI_CoreTalentIcon_yinzhenzhike_Icon_128',
#     'talent_description': '饮鸩止渴欺诈之神+25% 受伤缓冲生命濒危时，额外 -15% 受到的伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害'},
#    {'talent_id': 'Curse_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '2.5% 移动速度'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击与施法速度'},
#    {'talent_id': 'EsReg_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大护盾+3% 护盾充能速度'},
#    {'talent_id': 'Claw01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命'},
#    {'talent_id': 'Crit03_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+15% 暴击值'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 技能范围'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+6% 凋零几率+9% 凋零伤害'},
#    {'talent_id': 'Dot_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+2 每秒施加加剧值+9% 持续伤害'},
#    {'talent_id': 'Defence02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大护盾'},
#    {'talent_id': 'Defence02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+5 敏捷+5 智慧'},
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+2% 凋零持续时间附加 8 基础凋零伤害'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 持续伤害'}],
#   'mid_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害'},
#    {'talent_id': 'Curse_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 移动速度'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击与施法速度'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 最大生命每秒自然回复 0.5% 生命'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+20% 暴击值+10% 暴击伤害'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+14% 技能范围'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+12% 凋零几率+18% 凋零伤害'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '造成持续伤害时，收割 0.015 秒持续伤害，该效果对同一目标有 1 秒冷却时间'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+4% 最大护盾+4% 护盾充能速度'},
#    {'talent_id': 'Bow03_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+10 敏捷+10 智慧'}],
#   'legend_mid_talent_lst': [{'talent_id': 'Defence02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+16% 最大护盾护盾开始充能时，获得迷踪'},
#    {'talent_id': 'Cannon01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 持续技能等级'},
#    {'talent_id': 'Claw02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '8% 几率额外造成 1 层凋零每造成 5 层凋零，获得迷踪'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '对生命造成额外 10% 伤害'}]},
#  'God_of_Machines': {'talent_name': '机械之神',
#   'talent_main_attribute': ['力量'],
#   'talent_tags': ['召唤', '哨卫'],
#   'main_talent_lst': [{'talent_name': '号令',
#     'talent_id': 'UI_CoreTalentIcon_haoling_Icon_128',
#     'talent_description': '号令机械之神额外 +20% 召唤物伤害额外 +100% 召唤技能施法速度',
#     'talent_type': 'main'},
#    {'talent_name': '哨兵',
#     'talent_id': 'UI_CoreTalentIcon_shaobing_Icon_128',
#     'talent_description': '哨兵机械之神+1 哨卫数量上限放置哨卫的技能额外 +100% 施法速度',
#     'talent_type': 'main'},
#    {'talent_name': '龟缩',
#     'talent_id': 'UI_CoreTalentIcon_guisuo_Icon_128',
#     'talent_description': '龟缩机械之神受到伤害时， +50% 几率获得屏障',
#     'talent_type': 'main'},
#    {'talent_name': '强力护卫',
#     'talent_id': 'UI_CoreTalentIcon_qianglihuwei_Icon_128',
#     'talent_description': '强力护卫机械之神+2 召唤召唤物的技能等级每秒统御值增加 4 点魔灵 +40 初始生长值',
#     'talent_type': 'main'},
#    {'talent_name': '过度改装',
#     'talent_id': 'UI_CoreTalentIcon_guodugaizhuang_Icon_128',
#     'talent_description': '过度改装机械之神额外 +30% 哨卫伤害，额外 -50% 非哨卫主动技能伤害',
#     'talent_type': 'main'},
#    {'talent_name': '同构武装',
#     'talent_id': 'UI_CoreTalentIcon_tonggouwuzhuang_Icon_128',
#     'talent_description': '同构武装机械之神召唤物获得主手武器的加成额外 +15% 召唤物攻击和施法速度',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害+9% 召唤物伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 召唤物攻击与施法速度每秒自然回复 4 魔力'},
#    {'talent_id': 'Bow01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 哨卫技能范围+10% 哨卫持续时间4.5% 哨卫投射物速度'},
#    {'talent_id': 'Crit03_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+15% 召唤物暴击值+7% 召唤物技能范围'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命+3% 最大护盾'},
#    {'talent_id': 'Channel02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+30% 哨卫技能暴击值'},
#    {'talent_id': 'Axe02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 召唤物伤害'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8% 屏障吸收量'},
#    {'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+12% 哨卫伤害'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 召唤物伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '每秒统御值增加 1 点魔灵 +2% 强化技能使用几率'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '每秒自然回复 0.4% 生命+2% 护盾充能速度+2% 移动速度'},
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+4% 哨卫技能释放频率'}],
#   'mid_talent_lst': [{'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害+18% 召唤物伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 召唤物攻击与施法速度每秒自然回复 8 魔力'},
#    {'talent_id': 'Bow01_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+7% 哨卫技能范围+20% 哨卫持续时间+9% 哨卫投射物速度'},
#    {'talent_id': 'Crit03_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+15% 召唤物暴击伤害+10% 召唤物技能范围'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+6% 最大护盾'},
#    {'talent_id': 'Dagger02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+45% 哨卫技能暴击值+10% 哨卫技能暴击伤害'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 召唤物伤害'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '魔灵 +10% 冷却回复速度'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+16% 屏障吸收量'},
#    {'talent_id': 'Crossbow02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+24% 哨卫伤害'},
#    {'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '每秒统御值增加 2 点魔灵 +6% 强化技能使用几率'},
#    {'talent_id': 'Bow02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+8% 哨卫技能释放频率'}],
#   'legend_mid_talent_lst': [{'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 召唤召唤物的技能等级'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+25% 生命自然回复速度额外 -30% 护盾充能间隔+12% 移动速度'},
#    {'talent_id': 'Dual01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '如果近 1 秒内没有使用哨卫技能，额外 +12% 哨卫伤害'}]},
#  'The_Brave': {'talent_name': '勇者',
#   'talent_main_attribute': [],
#   'talent_tags': ['单手武器', '护甲'],
#   'main_talent_lst': [{'talent_name': '审判',
#     'talent_id': 'UI_CoreTalentIcon_shenpan_Icon_128',
#     'talent_description': '审判勇者攻击击中时， +100% 几率造成瘫痪对瘫痪敌人， 额外 +20% 暴击伤害',
#     'talent_type': 'main'},
#    {'talent_name': '坚毅',
#     'talent_id': 'UI_CoreTalentIcon_jianyi_Icon_128',
#     'talent_description': '坚毅勇者每有 1 层坚韧祝福， 额外 +4% 护甲值',
#     'talent_type': 'main'},
#    {'talent_name': '合力',
#     'talent_id': 'UI_CoreTalentIcon_heli_Icon_128',
#     'talent_description': '合力勇者双持时，副手武器不参与攻击附加 100% 副手武器伤害至主手武器',
#     'talent_type': 'main'},
#    {'talent_name': '势均力敌',
#     'talent_id': 'UI_CoreTalentIcon_shijunlidi_Icon_128',
#     'talent_description': '势均力敌勇者双持时，额外 +30% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '灰烬装甲',
#     'talent_id': 'UI_CoreTalentIcon_huijinzhuangjia_Icon_128',
#     'talent_description': '灰烬装甲勇者对非物理伤害，+25% 护甲有效率',
#     'talent_type': 'main'},
#    {'talent_name': '大象无形',
#     'talent_id': 'UI_CoreTalentIcon_daxiangwuxing_Icon_128',
#     'talent_description': '大象无形勇者战吼立即释放额外 +25% 近战伤害',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 攻击伤害'},
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 护甲值'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击速度'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+450 护甲值'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+15% 攻击暴击值'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+4% 攻击格挡率'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命+3% 最大护盾'},
#    {'talent_id': 'Axe01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '1.5% 生命返还'},
#    {'talent_id': 'Curse_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+10% 坚韧祝福持续时间拥有坚韧祝福时， 1.5% 元素抗性'},
#    {'talent_id': 'DmgPhys_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 攻击伤害'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+5% 投射物速度'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 战吼技能范围'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '- 30 受到的物理伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 攻击伤害'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 护甲值'},
#    {'talent_id': 'DmgEle_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8 力量'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 护甲值'}],
#   'mid_talent_lst': [{'talent_id': 'Accuracy_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 攻击伤害'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 最大生命每秒自然回复 0.5% 生命'},
#    {'talent_id': 'Defence03_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+14% 护甲值'},
#    {'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击速度击中时，回复 3 魔力'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+900 护甲值'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+20% 攻击暴击值+5% 暴击伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击格挡率+15% 从盾牌获得的防御值'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+6% 最大护盾'},
#    {'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+3% 生命返还'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '受到伤害时，+25% 几率获得 1 层坚韧祝福，间隔 1 秒'},
#    {'talent_id': 'DmgPhys_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 攻击伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+10% 投射物速度'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+14% 战吼技能范围'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '双持时， +8% 连续攻击几率双持时， +6% 攻击格挡率'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '持盾时， +8% 攻击速度'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+4% 几率获得双倍护甲效果'}],
#   'legend_mid_talent_lst': [{'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每有 1 层坚韧祝福， +8% 护甲值'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+5 战吼至少影响的敌人数量'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '额外 -20% 受到的元素伤害'},
#    {'talent_id': 'Dual01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '双持时，连续攻击伤害递增 20%'},
#    {'talent_id': 'Dual02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '持盾时，额外 +8% 主手武器伤害持盾时，+5% 移动速度'},
#    {'talent_id': 'Channel01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每 10 点力量， +1% 护甲值'},
#    {'talent_id': 'Dot_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+50% 从胸甲获得的防御值'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每 3000 点护甲， 0.5% 元素抗性，至多 6%每 3000 点护甲， 0.5% 腐蚀抗性，至多 6%'}]},
#  'Onslaughter': {'talent_name': '猛袭者',
#   'talent_main_attribute': [],
#   'talent_tags': ['双手武器', '生命'],
#   'main_talent_lst': [{'talent_name': '借势',
#     'talent_id': 'UI_CoreTalentIcon_jieshi_Icon_128',
#     'talent_description': '借势猛袭者每隔 0.5 秒，下一次核心技能额外 +30% 攻击伤害；击败时，刷新此间隔',
#     'talent_type': 'main'},
#    {'talent_name': '秘法',
#     'talent_id': 'UI_CoreTalentIcon_mifa_Icon_128',
#     'talent_description': '秘法猛袭者魔力消耗的 100% 转换为生命消耗额外 +20% 最大生命',
#     'talent_type': 'main'},
#    {'talent_name': '舍命',
#     'talent_id': 'UI_CoreTalentIcon_sheming_Icon_128',
#     'talent_description': '舍命猛袭者坚韧祝福的基础效果转换为：额外 +8% 伤害',
#     'talent_type': 'main'},
#    {'talent_name': '善始善终',
#     'talent_id': 'UI_CoreTalentIcon_shanshishanzhong_Icon_128',
#     'talent_description': '善始善终猛袭者生命濒危时，额外 +30% 攻击伤害',
#     'talent_type': 'main'},
#    {'talent_name': '生命通道',
#     'talent_id': 'UI_CoreTalentIcon_shengmingtongdao_Icon_128',
#     'talent_description': '生命通道猛袭者生命返还量翻倍生命返还仅在生命小于 50% 时生效',
#     'talent_type': 'main'},
#    {'talent_name': '生存意志',
#     'talent_id': 'UI_CoreTalentIcon_shengcunyizhi_Icon_128',
#     'talent_description': '生存意志猛袭者生命濒危时，额外 +100% 生命自然回复速度受击后 2 秒内，每秒自然回复 1% 生命，最多叠加 15 层',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 攻击伤害'},
#    {'talent_id': 'EsReg_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 防御值'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击速度'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '每秒自然回复 0.4% 生命'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+15% 攻击暴击值'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+5% 投射物速度'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 护甲值'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 攻击伤害'},
#    {'talent_id': 'Crit02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '1.5% 生命返还'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '额外 1.5% 武器伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+4% 攻击格挡率'},
#    {'talent_id': 'Channel03_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命'},
#    {'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击速度'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 位移技能攻击与施法速度'},
#    {'talent_id': 'Crit03_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8 力量'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 攻击伤害'}],
#   'mid_talent_lst': [{'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 攻击伤害'},
#    {'talent_id': 'Defence01_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 防御值'},
#    {'talent_id': 'Bow01_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击速度击中时，回复 4 魔力'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '每秒自然回复 0.8% 生命'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+20% 攻击暴击值+5% 暴击伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+10% 投射物速度'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+30% 攻击伤害-5% 攻击速度'},
#    {'talent_id': 'Dot_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+3% 生命返还'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '额外 +3% 近战双手武器基础伤害'},
#    {'talent_id': 'AtkSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '额外 +3% 远程双手武器基础攻击速度'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击格挡率持双手武器时， +2% 格挡比例'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+10% 技能消耗+8% 生命自然回复速度'},
#    {'talent_id': 'Bow03_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命-8% 技能消耗'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '对生命造成额外 4% 伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 位移技能攻击与施法速度'},
#    {'talent_id': 'Channel02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+80 最大生命'}],
#   'legend_mid_talent_lst': [{'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+16% 护甲值受到重创时，回复 20% 已损生命'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '额外 -20% 生命返还间隔使用攻击技能时，消耗 2% 当前生命'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '对生命健康敌人，额外 +40% 攻击伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每损失1%生命， 0.4% 攻击速度'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '使用位移技能后，额外 +12% 伤害，持续 2 秒'},
#    {'talent_id': 'Dot_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每 4 点力量， +1 点最大生命'}]},
#  'Warlord': {'talent_name': '督军',
#   'talent_main_attribute': [],
#   'talent_tags': ['火焰', '范围'],
#   'main_talent_lst': [{'talent_name': '野火',
#     'talent_id': 'UI_CoreTalentIcon_yehuo_Icon_128',
#     'talent_description': '野火督军对生命濒危敌人造成的火焰伤害额外 +100%召唤物对生命濒危敌人造成的火焰伤害额外 +100%',
#     'talent_type': 'main'},
#    {'talent_name': '清扫',
#     'talent_id': 'UI_CoreTalentIcon_qingsao_Icon_128',
#     'talent_description': '清扫督军最近每击败 1 个敌人，+10% 技能范围，至多 100%',
#     'talent_type': 'main'},
#    {'talent_name': '磐石',
#     'talent_id': 'UI_CoreTalentIcon_jianruopanshi_Icon_128',
#     'talent_description': '磐石督军每有 1 层坚韧祝福， +3% 火焰穿透',
#     'talent_type': 'main'},
#    {'talent_name': '真实之焰',
#     'talent_id': 'UI_CoreTalentIcon_zhenshizhiyan_Icon_128',
#     'talent_description': '真实之焰督军敌人被点燃时，加剧对其受到的持续伤害额外加成的 60% 同样作用于你的击中火焰伤害',
#     'talent_type': 'main'},
#    {'talent_name': '聚能之击',
#     'talent_id': 'UI_CoreTalentIcon_junengzhiji_Icon_128',
#     'talent_description': '聚能之击督军范围技能对中心敌人造成至多 32% 额外伤害召唤物的范围技能对中心敌人造成至多 32% 额外伤害',
#     'talent_type': 'main'},
#    {'talent_name': '星星之火',
#     'talent_id': 'UI_CoreTalentIcon_xinhuo_Icon_128',
#     'talent_description': '星星之火督军+1 点燃上限+30% 点燃持续时间',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 火焰伤害+9% 召唤物火焰伤害'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命+3% 最大护盾'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 范围伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 攻击与施法速度+3% 召唤物攻击与施法速度'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '4.5% 投射物速度+9% 召唤物投射物速度'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+6% 点燃几率+8% 点燃伤害召唤物 +10% 点燃几率'},
#    {'talent_id': 'Accuracy_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+4% 最大魔力'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 护甲值'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 火焰伤害+9% 召唤物火焰伤害'},
#    {'talent_id': 'Blind_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命'},
#    {'talent_id': 'Crit01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+15% 暴击值+15% 召唤物暴击值'},
#    {'talent_id': 'Defence02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '1.5% 生命返还1.5% 护盾返还'},
#    {'talent_id': 'Dagger03_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 技能范围'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 火焰伤害+9% 召唤物火焰伤害'},
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+10% 坚韧祝福持续时间拥有坚韧祝福时， 1.5% 元素抗性'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 火焰伤害+9% 召唤物火焰伤害'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+8 力量'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 范围伤害'},
#    {'talent_id': 'Dot_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 火焰持续伤害+9% 召唤物火焰伤害附加 10 基础点燃伤害'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害'}],
#   'mid_talent_lst': [{'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 火焰伤害+18% 召唤物火焰伤害'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+6% 最大护盾'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 范围伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击与施法速度+6% 召唤物攻击与施法速度'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+9% 投射物速度+18% 召唤物投射物速度'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+16% 点燃伤害+12% 点燃几率召唤物 +20% 点燃几率'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+8% 最大魔力'},
#    {'talent_id': 'DmgEle_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+10% 护甲值2.5% 元素抗性'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+3% 火焰穿透召唤物 +3% 火焰穿透'},
#    {'talent_id': 'Crit04_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+20% 暴击值+20% 召唤物暴击值+5% 暴击伤害+5% 召唤物暴击伤害'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+3% 生命返还+3% 护盾返还'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+14% 技能范围'},
#    {'talent_id': 'Axe02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '对生命濒危敌人， +45% 火焰伤害对生命濒危敌人， +45% 召唤物造成的火焰伤害'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 几率造成双倍伤害'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+15% 加剧效果+15% 召唤物加剧效果+8 每秒施加加剧值+8 召唤物每秒施加加剧值'}],
#   'legend_mid_talent_lst': [{'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+15% 最大生命每秒自然回复 1.5% 生命召唤物免疫火焰伤害'},
#    {'talent_id': 'DmgPhys_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '100% 物理伤害转化为火焰伤害召唤物 100% 物理伤害转化为火焰伤害'},
#    {'talent_id': 'Defence03_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 坚韧祝福层数上限'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+15% 力量'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '额外造成 1 层点燃'},
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '如果近 2 秒内没有使用核心技能，+40% 技能范围'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '范围技能造成伤害时，使敌人虚弱'}]},
#  'Marksman': {'talent_name': '神射手',
#   'talent_main_attribute': [],
#   'talent_tags': ['投射物', '闪避'],
#   'main_talent_lst': [{'talent_name': '狂风',
#     'talent_id': 'UI_CoreTalentIcon_kuangfeng_Icon_128',
#     'talent_description': '狂风神射手对投射物速度加成的 40% 同样作用于对伤害的额外加成',
#     'talent_type': 'main'},
#    {'talent_name': '心流',
# ...
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 屏障吸收量'},
#    {'talent_id': 'DmgEle_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+2% 元素抗性'},
#    {'talent_id': 'Channel01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害+9% 召唤物伤害'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 伤害+9% 召唤物伤害'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+2% 最大生命每秒自然回复 0.4% 生命'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 腐蚀伤害'},
#    {'talent_id': 'Bow03_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+2% 光环效果'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '伤害穿透 2% 元素抗性召唤物伤害穿透 2% 元素抗性'}],
#   'mid_talent_lst': [{'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 伤害+18% 召唤物伤害'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+6% 最大护盾'},
#    {'talent_id': 'DmgEle_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+4% 元素抗性'},
#    {'talent_id': 'CastSpeed_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 攻击与施法速度+6% 召唤物攻击与施法速度'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+3% 生命返还+3% 护盾返还'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+8% 最大魔力'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+5% 最大护盾+4% 护盾充能速度'},
#    {'talent_id': 'DmgChaos_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+8% 腐蚀抗性'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+1 激发技能等级'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+600 护甲值+10% 护甲值'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+9% 投射物速度+18% 召唤物投射物速度'},
#    {'talent_id': 'Freeze_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+14% 屏障吸收量'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '额外 -8% 受到的元素伤害'},
#    {'talent_id': 'DmgPhys_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+1 加持技能等级'},
#    {'talent_id': 'DmgChaos_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+1% 腐蚀抗性上限3% 受到的物理和元素伤害转化为腐蚀伤害'},
#    {'talent_id': 'Axe02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+4% 光环效果'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '伤害穿透 4% 元素抗性召唤物伤害穿透 4% 元素抗性'}],
#   'legend_mid_talent_lst': [{'talent_id': 'DmgEle_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '20% 受到的物理伤害转化为随机元素伤害'},
#    {'talent_id': 'Axe01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '击败时， +10% 伤害，持续 4 秒，最多叠加 8 层'},
#    {'talent_id': 'Dagger01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '每损失1%生命， +2% 回复技能效果'},
#    {'talent_id': 'Bow02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '击败时， +3% 移动速度，持续 4 秒，最多叠加 8 层'},
#    {'talent_id': 'Channel02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '对生命造成额外 10% 伤害'}]},
#  'Alchemist': {'talent_name': '炼金术士',
#   'talent_main_attribute': [],
#   'talent_tags': ['魔灵', '回复'],
#   'main_talent_lst': [{'talent_name': '源泉',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '源泉炼金术士魔灵技能 +50% 魔力封印补偿额外 +30% 魔灵之源效果魔灵额外 +30% 激发技能效果',
#     'talent_type': 'main'},
#    {'talent_name': '应急',
#     'talent_id': 'UI_CoreTalentIcon_yingji_Icon_128',
#     'talent_description': '应急炼金术士每损失 2% 生命，1.5% 生命自然回复速度每损失 2% 魔力，1.5% 魔力自然回复速度',
#     'talent_type': 'main'},
#    {'talent_name': '赋能',
#     'talent_id': 'UI_CoreTalentIcon_funeng_Icon_128',
#     'talent_description': '赋能炼金术士附加 25% 最大生命至屏障吸收量附加 25% 最大护盾至屏障吸收量',
#     'talent_type': 'main'},
#    {'talent_name': '冲锋号角',
#     'talent_id': 'UI_CoreTalentIcon_chongfenghaojiao_Icon_128',
#     'talent_description': '冲锋号角炼金术士额外 -10% 召唤物攻击和施法速度魔灵 +50% 强化技能使用几率',
#     'talent_type': 'main'},
#    {'talent_name': '活性超流',
#     'talent_id': 'UI_CoreTalentIcon_huoxingchaoliu_Icon_128',
#     'talent_description': '活性超流炼金术士溢出的魔力自然回复作用于生命每秒自然回复 4% 魔力',
#     'talent_type': 'main'},
#    {'talent_name': '深渊爪牙',
#     'talent_id': 'UI_CoreTalentIcon_shenyuanzhaoya_Icon_128',
#     'talent_description': '深渊爪牙炼金术士魔灵每有 20 点生长值，额外 +1% 伤害魔灵每有 40 点生长值，额外 +1% 冷却回复速度',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 召唤物伤害+9% 伤害'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命+4% 召唤物最大生命'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+6% 最大魔力'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 召唤物攻击与施法速度+3% 攻击与施法速度'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '每秒自然回复 0.4% 生命'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 召唤物移动速度召唤物 +8% 几率造成异常状态'},
#    {'talent_id': 'Defence02_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大护盾'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '每秒自然回复 0.4% 魔力'},
#    {'talent_id': 'Crit04_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+15% 召唤物暴击值'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 生命自然回复速度+12% 魔力自然回复速度'},
#    {'talent_id': 'DmgEle_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+9% 召唤物伤害'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+2% 移动速度'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '回复技能每秒获得 0.5 充能进度'},
#    {'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 护甲值'},
#    {'talent_id': 'DmgExtra_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '魔灵技能 +3% 魔力封印补偿'},
#    {'talent_id': 'Defence03_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+7% 屏障吸收量'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+3% 最大生命+3% 最大护盾'},
#    {'talent_id': 'DmgEle_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '+4% 魔灵之源效果魔灵 +9% 激发技能效果'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'mini',
#     'talent_description': '回复技能 +8% 回复效果'}],
#   'mid_talent_lst': [{'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+18% 召唤物伤害+18% 伤害'},
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+8% 召唤物最大生命'},
#    {'talent_id': 'Duration_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+12% 最大魔力'},
#    {'talent_id': 'Accuracy_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 召唤物攻击与施法速度+6% 攻击与施法速度'},
#    {'talent_id': 'Flask01_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '每秒自然回复 0.8% 生命'},
#    {'talent_id': 'Agi_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 召唤物移动速度召唤物 +16% 几率造成异常状态'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大护盾'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '每秒自然回复 0.8% 魔力'},
#    {'talent_id': 'DmgAll_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+20% 召唤物暴击值+5% 召唤物暴击伤害'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 生命自然回复速度+24% 魔力自然回复速度'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '魔灵 +4% 强化技能使用几率'},
#    {'talent_id': 'DmgEle_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '魔灵 -4% 强化技能使用几率+30% 召唤物伤害'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '周围每有1个召唤物， 1.5% 移动速度'},
#    {'talent_id': 'Area_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '回复技能生效期间，+24% 伤害'},
#    {'talent_id': 'Es_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '+6% 最大生命+6% 最大护盾'}],
#   'legend_mid_talent_lst': [{'talent_id': 'Armor_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+16% 护甲值附加 0.5% 护甲值至屏障吸收量'},
#    {'talent_id': 'Flask02_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 魔灵技能等级魔灵额外 -80% 受到的伤害'},
#    {'talent_id': 'Dual01_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '受到重创时，获得屏障'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '10% 受到的伤害转移至随机召唤物魔灵额外 -80% 受到的伤害'},
#    {'talent_id': 'Evasion_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+1 魔灵最大数量上限额外 -40% 魔灵技能伤害'},
#    {'talent_id': 'Defence03_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '+10% 屏障吸收比例'},
#    {'talent_id': 'DmgFire_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '回复技能生效期间， 额外 -25% 受到的持续伤害'},
#    {'talent_id': 'Dual03_64',
#     'talent_name': '',
#     'talent_type': 'legend_mid',
#     'talent_description': '额外 +16% 生命自然回复速度额外 -45% 护盾充能间隔'}]},
#  'New_God': {'talent_name': '新神',
#   'talent_main_attribute': [],
#   'talent_tags': [],
#   'main_talent_lst': [{'talent_name': '万界如常',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '万界如常新神每 3 秒获得 1 点秩序值',
#     'talent_type': 'main'},
#    {'talent_name': '万界祸乱',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '万界祸乱新神击败时，失去 1 点秩序值首次遭遇首领敌人时，失去一半当前的秩序值',
#     'talent_type': 'main'},
#    {'talent_name': '万界入寂',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '万界入寂新神固定拥有 50 点秩序值+25% 秩序值效果+25% 混乱值效果',
#     'talent_type': 'main'},
#    {'talent_name': '龙息绝',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '龙息绝新神吞噬坚韧祝福后，接下来若干次核心攻击技能 +100% 技能范围且额外 +60% 伤害，每吞噬 1 层坚韧祝福，该次数 +1新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '繁星坠',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '繁星坠新神吞噬灵动祝福后，接下来若干次核心攻击技能额外 +120% 攻击速度，接下来若干次核心法术技能额外 +120% 施法速度；每吞噬 1 层灵动祝福，该次数 +1；该效果对引导和哨卫技能无效新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '长梦醒',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '长梦醒新神吞噬聚能祝福后，接下来若干次核心法术技能 +100% 几率造成双倍伤害，每吞噬 1 层聚能祝福，该次数 +1新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '征伐终',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '征伐终新神吞噬战意后，每吞噬 1 点战意值，+4% 暴击伤害，并在接下来的 4 秒内衰减到 0新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '诳语破',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '诳语破新神吞噬迷踪后，每吞噬 1 点迷踪值，+1% 控制类状态效果，并在接下来的 4 秒内衰减到 0新神正在吞噬六神的恩泽',
#     'talent_type': 'main'},
#    {'talent_name': '高城覆',
#     'talent_id': 'UI_CoreTalentIcon_yuanquan_Icon_128',
#     'talent_description': '高城覆新神吞噬屏障后，每吞噬 1 点屏障值，在接下来的 4 秒内回复 1.5 点生命与护盾新神正在吞噬六神的恩泽',
#     'talent_type': 'main'}],
#   'mini_talent_lst': [],
#   'mid_talent_lst': [{'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 攻击伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，攻击 0.1% 几率造成双倍伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 火焰伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，对范围中心敌人额外 0.1% 伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 闪电伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，额外 0.11% 最大伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 法术伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，法术迸发释放的技能额外 0.1% 伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 冰冷伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，0.1% 施加的冰结值'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，1.5 暴击值'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，0.5% 暴击伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 物理伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，0.1% 几率无视护甲'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 持续伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，0.4% 收割时间每有 1 点混乱值，0.4% 加剧效果'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 腐蚀伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，0.05% 几率额外造成 1 层凋零'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 召唤物伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每 30 点混乱值，每秒获得 1 点统御值'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点秩序值，额外 0.15% 哨卫伤害'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '新神正在平衡秩序与混乱每有 1 点混乱值，额外 0.1% 哨卫技能释放频率'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '额外 -18% 秩序值降低速度'},
#    {'talent_id': 'Atk_64',
#     'talent_name': '',
#     'talent_type': 'mid',
#     'talent_description': '额外 +36% 秩序值降低速度'}],
#   'legend_mid_talent_lst': []}}

# %% [markdown]
# ## 2. 保存数据

# %%
save_json(talent_nodes,'talent.json')
